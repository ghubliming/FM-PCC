# %% [markdown]
# # FM-PCC Colab Workflow
#
# ---
#
# ## Run Order
# 1. Mount Drive
# 2. Clone/Update FM-PCC
# 3. Boost startup cache wiring
# 4. Install Miniconda + Create `FMPCC` env
# 5. Install D3IL
# 6. Install requirements with pinned compatibility
# 7. Set runtime env variables
# 8. Optional W&B relogin
# 9. Verify dependencies
# 10. Prepare dataset
# 11. Smoke test
# 12. Full train
# 13. Eval + visualization
# 14. Archive logs

# %%
# @title Notebook Version Marker
from datetime import datetime
import pytz

# Change 'UTC' to your local timezone if preferred (e.g., 'US/Eastern', 'Asia/Shanghai')
TIMEZONE = 'UTC'

now = datetime.now(pytz.timezone(TIMEZONE))
version_mark = now.strftime("%Y.%m.%d_%H%M%S")

print("=" * 40)
print(f"SESSION VERSION: {version_mark}")
print(f"START TIME     : {now.strftime('%A, %b %d, %Y - %I:%M:%S %p %Z')}")
print("=" * 40)
print("Trainig Eval FMv2 vs HP1 vs FN vs D")
# Out:
# ========================================
# SESSION VERSION: 2026.04.05_085150
# START TIME     : Sunday, Apr 05, 2026 - 08:51:50 AM UTC
# ========================================
# Trainig Eval FMv2 vs HP1 vs FN vs D

# %% [markdown]
# ## 1) Mount Google Drive

# %%
import os
from google.colab import drive

drive.mount('/content/drive', force_remount=True)

FMPCC_ROOT = '/content/drive/MyDrive/FMPCC'
REPO = f'{FMPCC_ROOT}/FM-PCC'
os.makedirs(FMPCC_ROOT, exist_ok=True)

print('Drive mounted')
print('Repo path:', REPO)
# Out:
# Mounted at /content/drive
# Drive mounted
# Repo path: /content/drive/MyDrive/FMPCC/FM-PCC

# %% [markdown]
# ## 2) Clone or Update FM-PCC

# %%
# @title Git Repository Sync
# @markdown Set this to 1 to replace any edited GitHub files with the latest versions.
# @markdown Your new files/notes will NOT be deleted.
OVERWRITE_LOCAL_CHANGES = "1" # @param [0, 1]
UPDATE_REPO = 1 # @param [0, 1]

import os
os.environ['OVERWRITE_LOCAL_CHANGES'] = str(OVERWRITE_LOCAL_CHANGES)
os.environ['UPDATE_REPO'] = str(UPDATE_REPO)

# %%
# %%bash
# set -e
#
# ROOT="/content/drive/MyDrive/FMPCC"
# REPO="$ROOT/FM-PCC"
# BRANCH="main" # You can change this if you ever decide to switch branches
#
# mkdir -p "$ROOT"
# cd "$ROOT"
#
# if [ ! -d "$REPO/.git" ]; then
#   echo "Cloning fresh repository..."
#   git clone --recurse-submodules https://github.com/ghubliming/FM-PCC.git
# else
#   cd "$REPO"
#
#   if [ "$UPDATE_REPO" != "1" ]; then
#     echo "Repo update disabled. Using existing local checkout."
#   else
#     echo "Fetching latest updates from GitHub..."
#     git fetch origin "$BRANCH"
#
#     if [ "$OVERWRITE_LOCAL_CHANGES" = "1" ]; then
#       echo "OVERWRITE_LOCAL_CHANGES=1: Resetting tracked files to match remote."
#       # This command ONLY affects files that exist in the Git repo.
#       # It does NOT touch your new notes or results.
#       git reset --hard "origin/$BRANCH"
#       git submodule update --init --recursive
#     else
#       # Check if there are any local edits to GitHub files
#       CHANGED_FILES="$(git status --porcelain | grep '^ M' || true)"
#       if [ -n "$CHANGED_FILES" ]; then
#         echo "WARNING: Local edits detected in GitHub files. Skipping update to protect them."
#         echo "Set OVERWRITE_LOCAL_CHANGES=1 to replace these files with the remote version."
#       else
#         echo "No conflicts found. Updating..."
#         git merge "origin/$BRANCH"
#         git submodule update --init --recursive
#       fi
#     fi
#   fi
# fi
#
# echo "------------------------------------------------"
# echo "Repo ready: $REPO"
# echo "Current Branch: $(git branch --show-current)"
# echo "------------------------------------------------"
#
# # This part specifically shows you what is yours (notes/new files)
# echo "Your Local Notes & New Files (Not in Git):"
# UNTRACKED="$(git ls-files --others --exclude-standard)"
# if [ -z "$UNTRACKED" ]; then
#   echo "  (None)"
# else
#   echo "$UNTRACKED"
# fi
# Out:
# Fetching latest updates from GitHub...
# OVERWRITE_LOCAL_CHANGES=1: Resetting tracked files to match remote.
# HEAD is now at 9837996 Merge pull request #11 from ghubliming/update_into_FM
# ------------------------------------------------
# Repo ready: /content/drive/MyDrive/FMPCC/FM-PCC
# Current Branch: main
# ------------------------------------------------
# Your Local Notes & New Files (Not in Git):
# args_resume_1.json
# args_resume_2.json
# args_resume_3.json
# args_resume_4.json
# args_resume_5.json
# args_resume_6.json
# args_resume_7.json
# args_resume_8.json
# args_resume_9.json
# d3il/
# logs_in_develop/load_results_outputs/seed5_DPCC/success_rates.png
# logs_in_develop/load_results_outputs/seed5_DPCC/success_rates_tightened.png
# logs_in_develop/load_results_outputs/seed5_DPCC/timesteps.png
# logs_in_develop/load_results_outputs/seed5_DPCC/timesteps_tightened.png
# logs_in_develop/load_results_outputs/seed6_DPCC/success_rates.png
# logs_in_develop/load_results_outputs/seed6_DPCC/success_rates_tightened.png
# logs_in_develop/load_results_outputs/seed6_DPCC/timesteps.png
# logs_in_develop/load_results_outputs/seed6_DPCC/timesteps_tightened.png
# logs_in_develop/load_results_outputs/seed6_gen2_FM_load_results_outputs/success_rates_fm.png
# logs_in_develop/load_results_outputs/seed6_gen2_FM_load_results_outputs/success_rates_tightened_fm.png
# logs_in_develop/load_results_outputs/seed6_gen2_FM_load_results_outputs/timesteps_fm.png
# logs_in_develop/load_results_outputs/seed6_gen2_FM_load_results_outputs/timesteps_tightened_fm.png
# wandb/debug-cli.root.log
# wandb/debug-internal.log
# wandb/debug.log
# wandb/latest-run
# wandb/run-20260319_162509-fl0dm9aq/files/conda-environment.yaml
# wandb/run-20260319_162509-fl0dm9aq/files/config.yaml
# wandb/run-20260319_162509-fl0dm9aq/files/output.log
# wandb/run-20260319_162509-fl0dm9aq/files/requirements.txt
# wandb/run-20260319_162509-fl0dm9aq/files/wandb-metadata.json
# wandb/run-20260319_162509-fl0dm9aq/files/wandb-summary.json
# wandb/run-20260319_162509-fl0dm9aq/logs/debug-internal.log
# wandb/run-20260319_162509-fl0dm9aq/logs/debug.log
# wandb/run-20260319_162509-fl0dm9aq/run-fl0dm9aq.wandb
# wandb/run-20260319_163154-1t4x5uur/files/conda-environment.yaml
# wandb/run-20260319_163154-1t4x5uur/files/config.yaml
# wandb/run-20260331_074427-69ssafq6/files/conda-environment.yaml
# wandb/run-20260331_074427-69ssafq6/files/config.yaml
# wandb/run-20260331_074427-69ssafq6/files/output.log
# wandb/run-20260331_074427-69ssafq6/files/requirements.txt
# wandb/run-20260331_074427-69ssafq6/files/wandb-metadata.json
# wandb/run-20260331_074427-69ssafq6/files/wandb-summary.json
# wandb/run-20260331_074427-69ssafq6/logs/debug-internal.log
# wandb/run-20260331_074427-69ssafq6/logs/debug.log
# wandb/run-20260331_074427-69ssafq6/run-69ssafq6.wandb
# wandb/run-20260402_100649-2v0dh90l/files/conda-environment.yaml
# wandb/run-20260402_100649-2v0dh90l/files/config.yaml
# wandb/run-20260402_100649-2v0dh90l/files/output.log
# wandb/run-20260402_100649-2v0dh90l/files/requirements.txt
# wandb/run-20260402_100649-2v0dh90l/files/wandb-metadata.json
# wandb/run-20260402_100649-2v0dh90l/files/wandb-summary.json
# wandb/run-20260402_100649-2v0dh90l/logs/debug-internal.log
# wandb/run-20260402_100649-2v0dh90l/logs/debug.log
# wandb/run-20260402_100649-2v0dh90l/run-2v0dh90l.wandb
# wandb/run-20260403_085525-wjtjvpqj/files/conda-environment.yaml
# wandb/run-20260403_085525-wjtjvpqj/files/config.yaml
# wandb/run-20260403_085525-wjtjvpqj/files/output.log
# wandb/run-20260403_085525-wjtjvpqj/files/requirements.txt
# wandb/run-20260403_085525-wjtjvpqj/files/wandb-metadata.json
# wandb/run-20260403_085525-wjtjvpqj/files/wandb-summary.json
# wandb/run-20260403_085525-wjtjvpqj/logs/debug-internal.log
# wandb/run-20260403_085525-wjtjvpqj/logs/debug.log
# wandb/run-20260403_085525-wjtjvpqj/run-wjtjvpqj.wandb
# wandb/run-20260403_091918-bfb4pow8/files/conda-environment.yaml
# wandb/run-20260403_091918-bfb4pow8/files/config.yaml
# wandb/run-20260403_091918-bfb4pow8/files/requirements.txt
# wandb/run-20260403_091918-bfb4pow8/files/wandb-metadata.json
# wandb/run-20260403_091918-bfb4pow8/logs/debug.log
# From https://github.com/ghubliming/FM-PCC
#  * branch            main       -> FETCH_HEAD
#    1255122..9837996  main       -> origin/main
# Updating files: 100% (257/257), done.

# %% [markdown]
# ## 3) Boost Startup Cache Wiring
#
# Keeps the original `/content/miniconda3` path logic, but maps it to Drive so restarts can reuse the same conda env and pip cache.

# %%
# %%bash
# set -e
#
# ROOT="/content/drive/MyDrive/FMPCC"
# PERSIST_CONDA="$ROOT/miniconda3"
# RUNTIME_CONDA="/content/miniconda3"
# PIP_CACHE="$ROOT/.pip-cache"
#
# mkdir -p "$ROOT" "$PIP_CACHE"
#
# if [ -L "$RUNTIME_CONDA" ]; then
#   rm -f "$RUNTIME_CONDA"
# elif [ -d "$RUNTIME_CONDA" ]; then
#   rm -rf "$RUNTIME_CONDA"
# fi
#
# ln -s "$PERSIST_CONDA" "$RUNTIME_CONDA"
#
# echo "Runtime conda path mapped to: $PERSIST_CONDA"
# echo "Persistent pip cache path: $PIP_CACHE"
# Out:
# Runtime conda path mapped to: /content/drive/MyDrive/FMPCC/miniconda3
# Persistent pip cache path: /content/drive/MyDrive/FMPCC/.pip-cache

# %% [markdown]
# ## 4) Install Miniconda and Create Env
#
# Keeps Python pinned to 3.10 for compatibility with project dependencies.

# %%
# %%bash
# set -e
#
# ROOT="/content/drive/MyDrive/FMPCC"
# PERSIST_CONDA="$ROOT/miniconda3"
# RUNTIME_CONDA="/content/miniconda3"
# CONDA_BIN="$PERSIST_CONDA/bin/conda"
# LOCAL_FALLBACK_CONDA="/content/miniconda3_runtime"
# CONDA_SNAPSHOT_DIR="$ROOT/cache"
# CONDA_SNAPSHOT="$CONDA_SNAPSHOT_DIR/fmpcc_conda_env.tar.gz"
# FORCE_REINSTALL_CONDA="${FORCE_REINSTALL_CONDA:-0}"
# REFRESH_CONDA_SNAPSHOT="${REFRESH_CONDA_SNAPSHOT:-0}"
#
# # Ensure the runtime path points to the persistent conda directory.
# if [ -L "$RUNTIME_CONDA" ]; then
#   LINK_TARGET="$(readlink -f "$RUNTIME_CONDA" || true)"
#   if [ "$LINK_TARGET" != "$PERSIST_CONDA" ]; then
#     rm -f "$RUNTIME_CONDA"
#     ln -s "$PERSIST_CONDA" "$RUNTIME_CONDA"
#   fi
# elif [ ! -e "$RUNTIME_CONDA" ]; then
#   ln -s "$PERSIST_CONDA" "$RUNTIME_CONDA"
# fi
#
# if [ "$FORCE_REINSTALL_CONDA" = "1" ]; then
#   echo "FORCE_REINSTALL_CONDA=1 -> reinstalling Miniconda"
#   rm -rf "$PERSIST_CONDA"
# fi
#
# if [ ! -d "$PERSIST_CONDA" ]; then
#   echo "First run detected: no persistent conda directory yet"
# fi
#
# # 1) Check if conda exists and works.
# NEED_CONDA_INSTALL=0
# if [ -x "$CONDA_BIN" ]; then
#   chmod +x "$PERSIST_CONDA/bin/python" "$PERSIST_CONDA/bin/conda" || true
#   if ! "$CONDA_BIN" --version >/tmp/conda_check.log 2>&1; then
#     if grep -qi "Permission denied" /tmp/conda_check.log; then
#       echo "Drive conda is not executable (permission denied). Switching to local runtime conda."
#       if [ -L "$RUNTIME_CONDA" ] || [ -e "$RUNTIME_CONDA" ]; then
#         rm -rf "$RUNTIME_CONDA"
#       fi
#       ln -s "$LOCAL_FALLBACK_CONDA" "$RUNTIME_CONDA"
#       PERSIST_CONDA="$LOCAL_FALLBACK_CONDA"
#       CONDA_BIN="$PERSIST_CONDA/bin/conda"
#       if [ -x "$CONDA_BIN" ]; then
#         echo "Reusing existing local runtime conda."
#       else
#         echo "No local runtime conda found yet; it will be installed now."
#         NEED_CONDA_INSTALL=1
#       fi
#     else
#       echo "Conda exists but failed health check -> reinstalling"
#       rm -rf "$PERSIST_CONDA"
#       NEED_CONDA_INSTALL=1
#     fi
#   else
#     echo "Conda exists and passed health check -> skip reinstall"
#   fi
# else
#   NEED_CONDA_INSTALL=1
# fi
#
# # 2) If there is a problem, reinstall.
# if [ "$NEED_CONDA_INSTALL" = "1" ]; then
#   if [ -f "$CONDA_SNAPSHOT" ]; then
#     echo "Restoring conda snapshot: $CONDA_SNAPSHOT"
#     rm -rf "$PERSIST_CONDA"
#     mkdir -p "$PERSIST_CONDA"
#     if ! tar -xzf "$CONDA_SNAPSHOT" -C "$PERSIST_CONDA" --strip-components=1; then
#       echo "Snapshot restore failed -> will run installer fallback"
#       rm -rf "$PERSIST_CONDA"
#     fi
#   fi
#
#   if [ ! -x "$CONDA_BIN" ] || ! "$CONDA_BIN" --version >/dev/null 2>&1; then
#     echo "Conda snapshot missing/broken -> installing Miniconda"
#     wget -q https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh -O /content/miniconda.sh
#     bash /content/miniconda.sh -b -p "$PERSIST_CONDA" -u
#   else
#     echo "Conda restored from snapshot"
#   fi
# fi
#
# "$CONDA_BIN" tos accept --override-channels --channel https://repo.anaconda.com/pkgs/main
# "$CONDA_BIN" tos accept --override-channels --channel https://repo.anaconda.com/pkgs/r
#
# if ! "$CONDA_BIN" env list | grep -q "^FMPCC "; then
#   "$CONDA_BIN" create -n FMPCC python=3.10 -y -q
# fi
#
# if [ ! -x "$PERSIST_CONDA/envs/FMPCC/bin/python" ] || [ ! -x "$PERSIST_CONDA/envs/FMPCC/bin/pip" ]; then
#   "$CONDA_BIN" remove -n FMPCC --all -y || true
#   "$CONDA_BIN" create -n FMPCC python=3.10 -y -q
# fi
#
# # If env binaries on Drive are not executable, switch to local runtime conda and rebuild env there.
# if ! "$PERSIST_CONDA/envs/FMPCC/bin/python" -V >/tmp/env_python_check.log 2>&1; then
#   if grep -qi "Permission denied" /tmp/env_python_check.log; then
#     echo "FMPCC env python is not executable on current path. Switching env to local runtime conda."
#     if [ -L "$RUNTIME_CONDA" ] || [ -e "$RUNTIME_CONDA" ]; then
#       rm -rf "$RUNTIME_CONDA"
#     fi
#     ln -s "$LOCAL_FALLBACK_CONDA" "$RUNTIME_CONDA"
#     PERSIST_CONDA="$LOCAL_FALLBACK_CONDA"
#     CONDA_BIN="$PERSIST_CONDA/bin/conda"
#
#     if [ ! -x "$CONDA_BIN" ]; then
#       wget -q https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh -O /content/miniconda.sh
#       bash /content/miniconda.sh -b -p "$PERSIST_CONDA" -u
#     fi
#
#     "$CONDA_BIN" tos accept --override-channels --channel https://repo.anaconda.com/pkgs/main
#     "$CONDA_BIN" tos accept --override-channels --channel https://repo.anaconda.com/pkgs/r
#     "$CONDA_BIN" remove -n FMPCC --all -y || true
#     "$CONDA_BIN" create -n FMPCC python=3.10 -y -q
#   else
#     cat /tmp/env_python_check.log
#     exit 1
#   fi
# fi
#
# "$PERSIST_CONDA/envs/FMPCC/bin/python" -V
# "$PERSIST_CONDA/envs/FMPCC/bin/pip" --version
#
# # Save a conda snapshot for fast restore on future Colab runtimes.
# mkdir -p "$CONDA_SNAPSHOT_DIR"
# if [ ! -f "$CONDA_SNAPSHOT" ] || [ "$REFRESH_CONDA_SNAPSHOT" = "1" ]; then
#   echo "Creating conda snapshot: $CONDA_SNAPSHOT"
#   if ! tar -czf "$CONDA_SNAPSHOT" -C "$PERSIST_CONDA" .; then
#     echo "Snapshot creation failed -> continuing without cache update"
#   fi
# else
#   echo "Conda snapshot exists -> skipping snapshot refresh"
# fi
# Out:
# Conda exists and passed health check -> skip reinstall
# accepted Terms of Service for https://repo.anaconda.com/pkgs/main
# accepted Terms of Service for https://repo.anaconda.com/pkgs/r
# FMPCC env python is not executable on current path. Switching env to local runtime conda.
# PREFIX=/content/miniconda3_runtime
# Unpacking bootstrapper...
# Unpacking payload...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /content/miniconda3_runtime
# accepted Terms of Service for https://repo.anaconda.com/pkgs/main
# accepted Terms of Service for https://repo.anaconda.com/pkgs/r
# Jupyter detected...
# 2 channel Terms of Service accepted
# Jupyter detected...
# 2 channel Terms of Service accepted
# Retrieving notices: ...working... done
# Channels:
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /content/miniconda3_runtime/envs/FMPCC
#
#   added / updated specs:
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2026.3.19  |       h06a4308_0         126 KB
#     ld_impl_linux-64-2.44      |       h9e0c5a2_3         725 KB
#     libexpat-2.7.5             |       h7354ed3_0         122 KB
#     libnsl-2.0.0               |       h5eee18b_0          31 KB
#     packaging-26.0             |  py310h06a4308_0         165 KB
#     pip-26.0.1                 |     pyhc872135_1         1.1 MB
#     python-3.10.20             |       h741d88c_0        24.1 MB
#     setuptools-82.0.1          |  py310h06a4308_0         1.2 MB
#     sqlite-3.51.2              |       h3e8d24a_0         1.2 MB
#     tzdata-2026a               |       he532380_0         117 KB
#     wheel-0.46.3               |  py310h06a4308_0          54 KB
#     ------------------------------------------------------------
#                                            Total:        29.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-1_gnu
#   bzip2              pkgs/main/linux-64::bzip2-1.0.8-h5eee18b_6
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2026.3.19-h06a4308_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.44-h9e0c5a2_3
#   libexpat           pkgs/main/linux-64::libexpat-2.7.5-h7354ed3_0
#   libffi             pkgs/main/linux-64::libffi-3.4.4-h6a678d5_1
#   libgcc             pkgs/main/linux-64::libgcc-15.2.0-h69a1729_7
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-15.2.0-h166f726_7
#   libgomp            pkgs/main/linux-64::libgomp-15.2.0-h4751f2c_7
#   libnsl             pkgs/main/linux-64::libnsl-2.0.0-h5eee18b_0
#   libstdcxx          pkgs/main/linux-64::libstdcxx-15.2.0-h39759b7_7
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-15.2.0-hc03a8fd_7
#   libuuid            pkgs/main/linux-64::libuuid-1.41.5-h5eee18b_0
#   libxcb             pkgs/main/linux-64::libxcb-1.17.0-h9b100fa_0
#   libzlib            pkgs/main/linux-64::libzlib-1.3.1-hb25bd0a_0
#   ncurses            pkgs/main/linux-64::ncurses-6.5-h7934f7d_0
#   openssl            pkgs/main/linux-64::openssl-3.5.5-h1b28b03_0
#   packaging          pkgs/main/linux-64::packaging-26.0-py310h06a4308_0
#   pip                pkgs/main/noarch::pip-26.0.1-pyhc872135_1
#   pthread-stubs      pkgs/main/linux-64::pthread-stubs-0.3-h0ce48e5_1
#   python             pkgs/main/linux-64::python-3.10.20-h741d88c_0
#   readline           pkgs/main/linux-64::readline-8.3-hc2a1206_0
#   setuptools         pkgs/main/linux-64::setuptools-82.0.1-py310h06a4308_0
#   sqlite             pkgs/main/linux-64::sqlite-3.51.2-h3e8d24a_0
#   tk                 pkgs/main/linux-64::tk-8.6.15-h54e0aa7_0
#   tzdata             pkgs/main/noarch::tzdata-2026a-he532380_0
#   wheel              pkgs/main/linux-64::wheel-0.46.3-py310h06a4308_0
#   xorg-libx11        pkgs/main/linux-64::xorg-libx11-1.8.12-h9b100fa_1
#   xorg-libxau        pkgs/main/linux-64::xorg-libxau-1.0.12-h9b100fa_0
#   xorg-libxdmcp      pkgs/main/linux-64::xorg-libxdmcp-1.1.5-h9b100fa_0
#   xorg-xorgproto     pkgs/main/linux-64::xorg-xorgproto-2024.1-h5eee18b_1
#   xz                 pkgs/main/linux-64::xz-5.8.2-h448239c_0
#   zlib               pkgs/main/linux-64::zlib-1.3.1-hb25bd0a_0
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Python 3.10.20
# pip 26.0.1 from /content/miniconda3_runtime/envs/FMPCC/lib/python3.10/site-packages/pip (python 3.10)
# Conda snapshot exists -> skipping snapshot refresh
# EnvironmentLocationNotFound: Not a conda environment: /content/miniconda3_runtime/envs/FMPCC

# %% [markdown]
# ## 5) Install D3IL (Install Once + Verify)
#
# Uses editable installs for both D3IL core and `gym_avoiding_env`, but skips reinstall when editable links already exist.

# %%
# %%bash
# set -e
#
# PIP="/content/miniconda3/envs/FMPCC/bin/pip"
# REPO="/content/drive/MyDrive/FMPCC/FM-PCC"
# D3IL="$REPO/d3il"
#
# if [ ! -d "$D3IL/.git" ]; then
#   echo "d3il missing/incomplete -> recloning"
#   rm -rf "$D3IL"
#   git clone https://github.com/ALRhub/d3il.git "$D3IL"
# fi
#
# if "$PIP" freeze | grep -Fq "d3il/environments/d3il" && "$PIP" freeze | grep -Fq "d3il/envs/gym_avoiding_env"; then
#   echo "D3IL editable installs already present; skipping reinstall"
# else
#   "$PIP" install -e "$D3IL/environments/d3il"
#   "$PIP" install -e "$D3IL/environments/d3il/envs/gym_avoiding_env"
# fi
#
# echo "D3IL installed"
# Out:
# Obtaining file:///content/drive/MyDrive/FMPCC/FM-PCC/d3il/environments/d3il
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: environments.d3il.d3il_sim
#   Building editable for environments.d3il.d3il_sim (pyproject.toml): started
#   Building editable for environments.d3il.d3il_sim (pyproject.toml): finished with status 'done'
#   Created wheel for environments.d3il.d3il_sim: filename=environments_d3il_d3il_sim-0.2-0.editable-py3-none-any.whl size=2970 sha256=684a7127e2e9d5b71c5275f417dcbd1f258f4e45073bbb7ad54ede28dc3d0403
#   Stored in directory: /tmp/pip-ephem-wheel-cache-o3hfrntf/wheels/c2/2f/ac/2f2eaaf8a5af74e02b2a4afffb7f356f04b0a6d72bded4ba17
# Successfully built environments.d3il.d3il_sim
# Installing collected packages: environments.d3il.d3il_sim
# Successfully installed environments.d3il.d3il_sim-0.2
# Obtaining file:///content/drive/MyDrive/FMPCC/FM-PCC/d3il/environments/d3il/envs/gym_avoiding_env
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Collecting gym (from gym_avoiding==0.0.1)
#   Downloading gym-0.26.2.tar.gz (721 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.7/721.7 kB 13.8 MB/s  0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting numpy>=1.18.0 (from gym->gym_avoiding==0.0.1)
#   Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting cloudpickle>=1.2.0 (from gym->gym_avoiding==0.0.1)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting gym_notices>=0.0.4 (from gym->gym_avoiding==0.0.1)
#   Downloading gym_notices-0.1.0-py3-none-any.whl.metadata (1.2 kB)
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading gym_notices-0.1.0-py3-none-any.whl (3.3 kB)
# Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 56.2 MB/s  0:00:00
# Building wheels for collected packages: gym_avoiding, gym
#   Building editable for gym_avoiding (pyproject.toml): started
#   Building editable for gym_avoiding (pyproject.toml): finished with status 'done'
#   Created wheel for gym_avoiding: filename=gym_avoiding-0.0.1-0.editable-py3-none-any.whl size=2750 sha256=3e0e41911957720a3bd3c294cc54e04cbbb652df58fd6094367bf84ab8f86bcd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vs7axdze/wheels/65/be/63/02bd0e04f2e3fa1e26024d72a5b0f478a7b2a797842e843d46
#   Building wheel for gym (pyproject.toml): started
#   Building wheel for gym (pyproject.toml): finished with status 'done'
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827728 sha256=85985939ae52ed9252c173e3b2343d08713532528bd4f80580557d774fb39b50
#   Stored in directory: /root/.cache/pip/wheels/b9/22/6d/3e7b32d98451b4cd9d12417052affbeeeea012955d437da1da
# Successfully built gym_avoiding gym
# Installing collected packages: gym_notices, numpy, cloudpickle, gym, gym_avoiding
#
# Successfully installed cloudpickle-3.1.2 gym-0.26.2 gym_avoiding-0.0.1 gym_notices-0.1.0 numpy-2.2.6
# D3IL installed

# %% [markdown]
# ## 6) Install Requirements (Install Once + Verify)
#
# Runs validation first and only installs when the environment is missing or inconsistent.

# %%
# %%bash
# set -e
#
# REPO="/content/drive/MyDrive/FMPCC/FM-PCC"
# PIP="/content/miniconda3/envs/FMPCC/bin/pip"
# PY="/content/miniconda3/envs/FMPCC/bin/python"
# PIP_CACHE="/content/drive/MyDrive/FMPCC/.pip-cache"
# CACHE_DIR="/content/drive/MyDrive/FMPCC/cache"
# REQ_FILE="$REPO/requirements.txt"
# REQ_HASH="$(sha256sum "$REQ_FILE" | awk '{print $1}')"
# WHEELHOUSE="$CACHE_DIR/wheelhouse_$REQ_HASH"
# REQ_STAMP="/content/miniconda3/envs/FMPCC/.fmpcc_requirements_hash"
# FORCE_REINSTALL_REQS="${FORCE_REINSTALL_REQS:-0}"
#
# mkdir -p "$PIP_CACHE" "$CACHE_DIR"
# cd "$REPO"
#
# if [ "$FORCE_REINSTALL_REQS" = "1" ]; then
#   echo "FORCE_REINSTALL_REQS=1 -> forcing requirements reinstall"
#   REQ_VALID=0
# elif "$PY" - <<'PY'
# import importlib
# import sys
#
# pkgs = [
#     'torch', 'numpy', 'scipy', 'gym', 'gymnasium', 'gymnasium_robotics',
#     'minari', 'wandb', 'mujoco', 'diffusers', 'transformers'
# ]
#
# ok = True
# for p in pkgs:
#     try:
#         importlib.import_module(p)
#     except Exception as e:
#         ok = False
#         print(f'Missing/broken package: {p} ({type(e).__name__}: {e})')
#
# import numpy
# if int(numpy.__version__.split('.')[0]) >= 2:
#     ok = False
#     print(f'Invalid numpy version: {numpy.__version__}; expected 1.x for this workflow')
#
# sys.exit(0 if ok else 2)
# PY
# then
#   REQ_VALID=1
# else
#   REQ_VALID=0
# fi
#
# if [ "$REQ_VALID" = "1" ]; then
#   if [ -f "$REQ_STAMP" ] && grep -Fxq "$REQ_HASH" "$REQ_STAMP"; then
#     echo "Package validation passed and requirements hash unchanged; skipping reinstall"
#   else
#     echo "Package validation passed but requirements hash stamp missing/changed; updating stamp only"
#     echo "$REQ_HASH" > "$REQ_STAMP"
#   fi
# else
#   echo "Package validation failed; installing requirements"
#
#   # Build or reuse a Drive-backed wheelhouse for faster future reinstalls.
#   if [ ! -d "$WHEELHOUSE" ] || [ -z "$(ls -A "$WHEELHOUSE" 2>/dev/null || true)" ]; then
#     echo "Building wheelhouse cache at: $WHEELHOUSE"
#     mkdir -p "$WHEELHOUSE"
#     PIP_CACHE_DIR="$PIP_CACHE" "$PIP" download -r requirements.txt -d "$WHEELHOUSE" || true
#   else
#     echo "Wheelhouse cache found: $WHEELHOUSE"
#   fi
#
#   WHEEL_COUNT="$(find "$WHEELHOUSE" -maxdepth 1 -type f \( -name '*.whl' -o -name '*.tar.gz' -o -name '*.zip' \) | wc -l)"
#   if [ "$WHEEL_COUNT" -gt 0 ] && PIP_CACHE_DIR="$PIP_CACHE" "$PIP" install --no-index --find-links "$WHEELHOUSE" -r requirements.txt; then
#     echo "Offline wheelhouse install succeeded"
#   else
#     echo "First run or incomplete wheelhouse -> running online install"
#     PIP_CACHE_DIR="$PIP_CACHE" "$PIP" install -r requirements.txt
#
#     # Backfill wheelhouse after a successful online install for faster future runs.
#     PIP_CACHE_DIR="$PIP_CACHE" "$PIP" download -r requirements.txt -d "$WHEELHOUSE" || true
#   fi
#
#   # pip check may report known non-fatal issues on Colab (platform/extra metadata).
#   PIP_CHECK_OUT="$("$PIP" check 2>&1 || true)"
#   echo "$PIP_CHECK_OUT"
#
#   UNEXPECTED_PIP_CHECK="$(echo "$PIP_CHECK_OUT" | grep -Ev '(^$|gurobipy .* is not supported on this platform|WARNING: typer .* does not provide the extra .all.)' || true)"
#   if [ -n "$UNEXPECTED_PIP_CHECK" ]; then
#     echo "Unexpected pip check issues found:"
#     echo "$UNEXPECTED_PIP_CHECK"
#     exit 1
#   else
#     echo "Only known non-fatal pip check warnings detected; continuing"
#   fi
#
#   echo "$REQ_HASH" > "$REQ_STAMP"
# fi
#
# # Quick sanity check
# "$PY" - <<'PY'
# import numpy, torch
# print("numpy:", numpy.__version__)
# print("torch:", torch.__version__)
# print("cuda:", torch.cuda.is_available())
# print("python:", __import__("sys").executable)
# PY
# Out:
# Missing/broken package: torch (ModuleNotFoundError: No module named 'torch')
# Missing/broken package: scipy (ModuleNotFoundError: No module named 'scipy')
# Missing/broken package: gymnasium (ModuleNotFoundError: No module named 'gymnasium')
# Missing/broken package: gymnasium_robotics (ModuleNotFoundError: No module named 'gymnasium_robotics')
# Missing/broken package: minari (ModuleNotFoundError: No module named 'minari')
# Missing/broken package: mujoco (ModuleNotFoundError: No module named 'mujoco')
# Missing/broken package: diffusers (ModuleNotFoundError: No module named 'diffusers')
# Missing/broken package: transformers (ModuleNotFoundError: No module named 'transformers')
# Invalid numpy version: 2.2.6; expected 1.x for this workflow
# Package validation failed; installing requirements
# Wheelhouse cache found: /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39
# Looking in links: /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/absl_py-2.1.0-py3-none-any.whl (from -r requirements.txt (line 1))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/accelerate-0.31.0-py3-none-any.whl (from -r requirements.txt (line 2))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/cachetools-5.3.3-py3-none-any.whl (from -r requirements.txt (line 3))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/casadi-3.6.5-cp310-none-manylinux2014_x86_64.whl (from -r requirements.txt (line 4))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/certifi-2024.6.2-py3-none-any.whl (from -r requirements.txt (line 5))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r requirements.txt (line 6))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/chex-0.1.86-py3-none-any.whl (from -r requirements.txt (line 7))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/clarabel-0.9.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r requirements.txt (line 8))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/click-8.1.7-py3-none-any.whl (from -r requirements.txt (line 9))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/cloudpickle-3.0.0-py3-none-any.whl (from -r requirements.txt (line 10))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/cmeel-0.53.3-py3-none-any.whl (from -r requirements.txt (line 11))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/cmeel_assimp-5.3.1-0-py3-none-manylinux_2_28_x86_64.whl (from -r requirements.txt (line 12))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/cmeel_boost-1.83.0-0-cp310-cp310-manylinux_2_28_x86_64.whl (from -r requirements.txt (line 13))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/cmeel_console_bridge-1.0.2.2-3-py3-none-manylinux_2_28_x86_64.whl (from -r requirements.txt (line 14))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/cmeel_octomap-1.9.8.2-3-py3-none-manylinux_2_28_x86_64.whl (from -r requirements.txt (line 15))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/cmeel_qhull-8.0.2.1-1-py3-none-manylinux_2_28_x86_64.whl (from -r requirements.txt (line 16))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/cmeel_tinyxml-2.6.2.3-0-py3-none-manylinux_2_28_x86_64.whl (from -r requirements.txt (line 17))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/cmeel_urdfdom-3.1.1.1-0-py3-none-manylinux_2_28_x86_64.whl (from -r requirements.txt (line 18))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/colorama-0.4.6-py2.py3-none-any.whl (from -r requirements.txt (line 19))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/contourpy-1.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r requirements.txt (line 20))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/cvxopt-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r requirements.txt (line 21))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/cvxpy-1.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r requirements.txt (line 22))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/cycler-0.12.1-py3-none-any.whl (from -r requirements.txt (line 23))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/diffusers-0.31.0-py3-none-any.whl (from -r requirements.txt (line 24))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/dill-0.3.8-py3-none-any.whl (from -r requirements.txt (line 25))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/docker_pycreds-0.4.0-py2.py3-none-any.whl (from -r requirements.txt (line 26))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/ecos-2.0.14-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r requirements.txt (line 27))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/eigenpy-3.5.1-0-cp310-cp310-manylinux_2_28_x86_64.whl (from -r requirements.txt (line 28))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/einops-0.8.0-py3-none-any.whl (from -r requirements.txt (line 29))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/etils-1.9.4-py3-none-any.whl (from -r requirements.txt (line 30))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/Farama_Notifications-0.0.4-py3-none-any.whl (from -r requirements.txt (line 31))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/filelock-3.13.1-py3-none-any.whl (from -r requirements.txt (line 32))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/flax-0.8.4-py3-none-any.whl (from -r requirements.txt (line 33))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/fonttools-4.53.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r requirements.txt (line 34))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/fsspec-2024.2.0-py3-none-any.whl (from -r requirements.txt (line 35))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/gin_config-0.5.0-py3-none-any.whl (from -r requirements.txt (line 36))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/gitdb-4.0.11-py3-none-any.whl (from -r requirements.txt (line 37))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/GitPython-3.1.43-py3-none-any.whl (from -r requirements.txt (line 38))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/glfw-2.7.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38-none-manylinux2014_x86_64.whl (from -r requirements.txt (line 39))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/google_api_core-2.19.0-py3-none-any.whl (from -r requirements.txt (line 40))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/google_auth-2.29.0-py2.py3-none-any.whl (from -r requirements.txt (line 41))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/google_cloud_core-2.4.1-py2.py3-none-any.whl (from -r requirements.txt (line 42))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/google_cloud_storage-2.16.0-py2.py3-none-any.whl (from -r requirements.txt (line 43))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/google_crc32c-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r requirements.txt (line 44))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/google_resumable_media-2.7.0-py2.py3-none-any.whl (from -r requirements.txt (line 45))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/googleapis_common_protos-1.63.0-py2.py3-none-any.whl (from -r requirements.txt (line 46))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/gurobipy-11.0.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (from -r requirements.txt (line 47))
# Requirement already satisfied: gym==0.26.2 in /content/miniconda3_runtime/envs/FMPCC/lib/python3.10/site-packages (from -r requirements.txt (line 48)) (0.26.2)
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/gym_notices-0.0.8-py3-none-any.whl (from -r requirements.txt (line 49))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/gymnasium-0.29.1-py3-none-any.whl (from -r requirements.txt (line 50))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/gymnasium_robotics-1.2.4-py3-none-any.whl (from -r requirements.txt (line 51))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/h5py-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r requirements.txt (line 52))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/hpp_fcl-2.4.4-3-cp310-cp310-manylinux_2_28_x86_64.whl (from -r requirements.txt (line 53))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/huggingface_hub-0.23.4-py3-none-any.whl (from -r requirements.txt (line 54))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/idna-3.7-py3-none-any.whl (from -r requirements.txt (line 55))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/imageio-2.34.1-py3-none-any.whl (from -r requirements.txt (line 56))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/importlib_metadata-7.1.0-py3-none-any.whl (from -r requirements.txt (line 57))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/importlib_resources-6.4.0-py3-none-any.whl (from -r requirements.txt (line 58))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/jax-0.4.28-py3-none-any.whl (from -r requirements.txt (line 59))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/jaxlib-0.4.28-cp310-cp310-manylinux2014_x86_64.whl (from -r requirements.txt (line 60))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/Jinja2-3.1.3-py3-none-any.whl (from -r requirements.txt (line 61))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/joblib-1.4.2-py3-none-any.whl (from -r requirements.txt (line 62))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (from -r requirements.txt (line 63))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/markdown_it_py-3.0.0-py3-none-any.whl (from -r requirements.txt (line 64))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r requirements.txt (line 65))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/matplotlib-3.9.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r requirements.txt (line 66))
# Collecting mc-bin-client==1.0.1 (from -r requirements.txt (line 67))
#   Using cached mc_bin_client-1.0.1-py3-none-any.whl
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/mdurl-0.1.2-py3-none-any.whl (from -r requirements.txt (line 68))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/minari-0.4.3-py3-none-any.whl (from -r requirements.txt (line 69))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/ml_dtypes-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r requirements.txt (line 70))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/mpmath-1.3.0-py3-none-any.whl (from -r requirements.txt (line 71))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/msgpack-1.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r requirements.txt (line 72))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/mujoco-2.3.7-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r requirements.txt (line 73))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/nest_asyncio-1.6.0-py3-none-any.whl (from -r requirements.txt (line 74))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/networkx-3.2.1-py3-none-any.whl (from -r requirements.txt (line 75))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r requirements.txt (line 76))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (from -r requirements.txt (line 77))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (from -r requirements.txt (line 78))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (from -r requirements.txt (line 79))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (from -r requirements.txt (line 80))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (from -r requirements.txt (line 81))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (from -r requirements.txt (line 82))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (from -r requirements.txt (line 83))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (from -r requirements.txt (line 84))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (from -r requirements.txt (line 85))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (from -r requirements.txt (line 86))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/nvidia_nvjitlink_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (from -r requirements.txt (line 87))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (from -r requirements.txt (line 88))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r requirements.txt (line 89))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/opt_einsum-3.3.0-py3-none-any.whl (from -r requirements.txt (line 90))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/optax-0.2.2-py3-none-any.whl (from -r requirements.txt (line 91))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/orbax_checkpoint-0.5.16-py3-none-any.whl (from -r requirements.txt (line 92))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/osqp-0.6.7.post0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r requirements.txt (line 93))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/packaging-24.0-py3-none-any.whl (from -r requirements.txt (line 94))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/pettingzoo-1.24.3-py3-none-any.whl (from -r requirements.txt (line 95))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/pillow-10.2.0-cp310-cp310-manylinux_2_28_x86_64.whl (from -r requirements.txt (line 96))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/pin-2.7.0-2-cp310-cp310-manylinux_2_28_x86_64.whl (from -r requirements.txt (line 97))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/platformdirs-4.2.2-py3-none-any.whl (from -r requirements.txt (line 98))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/portion-2.4.2-py3-none-any.whl (from -r requirements.txt (line 99))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/proto_plus-1.23.0-py3-none-any.whl (from -r requirements.txt (line 100))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl (from -r requirements.txt (line 101))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/proxsuite-0.6.6-0-cp310-cp310-manylinux_2_17_x86_64.whl (from -r requirements.txt (line 102))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/psutil-5.9.8-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r requirements.txt (line 103))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/pyarrow-16.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (from -r requirements.txt (line 104))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/pyasn1-0.6.0-py2.py3-none-any.whl (from -r requirements.txt (line 105))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/pyasn1_modules-0.4.0-py3-none-any.whl (from -r requirements.txt (line 106))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/pybullet-3.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r requirements.txt (line 107))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/pygments-2.18.0-py3-none-any.whl (from -r requirements.txt (line 108))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/PyOpenGL-3.1.7-py3-none-any.whl (from -r requirements.txt (line 109))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/pyparsing-3.1.2-py3-none-any.whl (from -r requirements.txt (line 110))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/PyQt5-5.15.10-cp37-abi3-manylinux_2_17_x86_64.whl (from -r requirements.txt (line 111))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/PyQt5_Qt5-5.15.2-py3-none-manylinux2014_x86_64.whl (from -r requirements.txt (line 112))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/PyQt5_sip-12.13.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.whl (from -r requirements.txt (line 113))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/python_dateutil-2.9.0.post0-py2.py3-none-any.whl (from -r requirements.txt (line 114))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r requirements.txt (line 115))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/qdldl-0.1.7.post4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r requirements.txt (line 116))
# Collecting qpth==0.0.17 (from -r requirements.txt (line 117))
#   Using cached qpth-0.0.17-py3-none-any.whl
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/regex-2024.5.15-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r requirements.txt (line 118))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/requests-2.32.3-py3-none-any.whl (from -r requirements.txt (line 119))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/rich-13.7.1-py3-none-any.whl (from -r requirements.txt (line 120))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/rsa-4.9-py3-none-any.whl (from -r requirements.txt (line 121))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/safetensors-0.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r requirements.txt (line 122))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/scikit_learn-1.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r requirements.txt (line 123))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/scipy-1.13.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r requirements.txt (line 124))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/scs-3.2.6-cp310-cp310-manylinux_2_28_x86_64.whl (from -r requirements.txt (line 125))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/sentry_sdk-2.12.0-py2.py3-none-any.whl (from -r requirements.txt (line 126))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r requirements.txt (line 127))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/shellingham-1.5.4-py2.py3-none-any.whl (from -r requirements.txt (line 128))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/six-1.16.0-py2.py3-none-any.whl (from -r requirements.txt (line 129))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/smmap-5.0.1-py3-none-any.whl (from -r requirements.txt (line 130))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/sortedcontainers-2.4.0-py2.py3-none-any.whl (from -r requirements.txt (line 131))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/sympy-1.12-py3-none-any.whl (from -r requirements.txt (line 132))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/tensorstore-0.1.62-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r requirements.txt (line 133))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/threadpoolctl-3.5.0-py3-none-any.whl (from -r requirements.txt (line 134))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r requirements.txt (line 135))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/toolz-0.12.1-py3-none-any.whl (from -r requirements.txt (line 136))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/tqdm-4.66.4-py3-none-any.whl (from -r requirements.txt (line 137))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/transformers-4.41.2-py3-none-any.whl (from -r requirements.txt (line 138))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/triton-2.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r requirements.txt (line 139))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/typer-0.12.3-py3-none-any.whl (from -r requirements.txt (line 140))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/typing_extensions-4.12.1-py3-none-any.whl (from -r requirements.txt (line 141))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/urllib3-2.2.1-py3-none-any.whl (from -r requirements.txt (line 142))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/wandb-0.17.5-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from -r requirements.txt (line 143))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/zipp-3.19.1-py3-none-any.whl (from -r requirements.txt (line 144))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/torch-2.2.2-cp310-cp310-manylinux1_x86_64.whl (from accelerate==0.31.0->-r requirements.txt (line 2))
# Processing /content/drive/MyDrive/FMPCC/cache/wheelhouse_7f51b2eecd675d29f593a4ec70084ed4251266c758f7a4374628942b33efaa39/tomli-2.4.0-py3-none-any.whl (from cmeel==0.53.3->-r requirements.txt (line 11))
# Requirement already satisfied: setuptools in /content/miniconda3_runtime/envs/FMPCC/lib/python3.10/site-packages (from wandb==0.17.5->-r requirements.txt (line 143)) (82.0.1)
# Installing collected packages: sortedcontainers, PyQt5-Qt5, PyOpenGL, pybullet, mpmath, mc-bin-client, gym-notices, gurobipy, glfw, gin-config, Farama-Notifications, zipp, urllib3, typing_extensions, tqdm, toolz, tomli, threadpoolctl, sympy, smmap, six, shellingham, setproctitle, safetensors, regex, PyYAML, PyQt5-sip, pyparsing, Pygments, pyasn1, psutil, protobuf, portion, platformdirs, pillow, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, nest-asyncio, msgpack, mdurl, MarkupSafe, kiwisolver, joblib, importlib_resources, idna, google-crc32c, fsspec, fonttools, filelock, etils, einops, dill, cycler, cvxopt, colorama, cloudpickle, click, charset-normalizer, certifi, cachetools, absl-py, triton, sentry-sdk, scipy, rsa, requests, python-dateutil, PyQt5, pyasn1_modules, pyarrow, proto-plus, opt-einsum, opencv-python, nvidia-cusparse-cu12, nvidia-cudnn-cu12, mujoco, ml-dtypes, markdown-it-py, Jinja2, importlib_metadata, imageio, h5py, gymnasium, googleapis-common-protos, google-resumable-media, gitdb, docker-pycreds, contourpy, cmeel, casadi, tensorstore, scs, scikit-learn, rich, qdldl, proxsuite, pettingzoo, nvidia-cusolver-cu12, matplotlib, jaxlib, jax, huggingface-hub, google-auth, GitPython, ecos, cmeel-tinyxml, cmeel-qhull, cmeel-octomap, cmeel-console-bridge, cmeel-boost, cmeel-assimp, clarabel, wandb, typer, torch, tokenizers, osqp, orbax-checkpoint, gymnasium-robotics, google-api-core, eigenpy, diffusers, cmeel-urdfdom, chex, transformers, optax, hpp-fcl, google-cloud-core, cvxpy, accelerate, qpth, pin, google-cloud-storage, flax, minari
#   Attempting uninstall: gym-notices
#     Found existing installation: gym-notices 0.1.0
#     Uninstalling gym-notices-0.1.0:
#       Successfully uninstalled gym-notices-0.1.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 26.0
#     Uninstalling packaging-26.0:
#       Successfully uninstalled packaging-26.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 3.1.2
#     Uninstalling cloudpickle-3.1.2:
#       Successfully uninstalled cloudpickle-3.1.2
#
# Successfully installed Farama-Notifications-0.0.4 GitPython-3.1.43 Jinja2-3.1.3 MarkupSafe-2.1.5 PyOpenGL-3.1.7 PyQt5-5.15.10 PyQt5-Qt5-5.15.2 PyQt5-sip-12.13.0 PyYAML-6.0.1 Pygments-2.18.0 absl-py-2.1.0 accelerate-0.31.0 cachetools-5.3.3 casadi-3.6.5 certifi-2024.6.2 charset-normalizer-3.3.2 chex-0.1.86 clarabel-0.9.0 click-8.1.7 cloudpickle-3.0.0 cmeel-0.53.3 cmeel-assimp-5.3.1 cmeel-boost-1.83.0 cmeel-console-bridge-1.0.2.2 cmeel-octomap-1.9.8.2 cmeel-qhull-8.0.2.1 cmeel-tinyxml-2.6.2.3 cmeel-urdfdom-3.1.1.1 colorama-0.4.6 contourpy-1.2.1 cvxopt-1.3.2 cvxpy-1.5.2 cycler-0.12.1 diffusers-0.31.0 dill-0.3.8 docker-pycreds-0.4.0 ecos-2.0.14 eigenpy-3.5.1 einops-0.8.0 etils-1.9.4 filelock-3.13.1 flax-0.8.4 fonttools-4.53.0 fsspec-2024.2.0 gin-config-0.5.0 gitdb-4.0.11 glfw-2.7.0 google-api-core-2.19.0 google-auth-2.29.0 google-cloud-core-2.4.1 google-cloud-storage-2.16.0 google-crc32c-1.5.0 google-resumable-media-2.7.0 googleapis-common-protos-1.63.0 gurobipy-11.0.3 gym-notices-0.0.8 gymnasium-0.29.1 gymnasium-robotics-1.2.4 h5py-3.11.0 hpp-fcl-2.4.4 huggingface-hub-0.23.4 idna-3.7 imageio-2.34.1 importlib_metadata-7.1.0 importlib_resources-6.4.0 jax-0.4.28 jaxlib-0.4.28 joblib-1.4.2 kiwisolver-1.4.5 markdown-it-py-3.0.0 matplotlib-3.9.0 mc-bin-client-1.0.1 mdurl-0.1.2 minari-0.4.3 ml-dtypes-0.4.0 mpmath-1.3.0 msgpack-1.0.8 mujoco-2.3.7 nest-asyncio-1.6.0 networkx-3.2.1 numpy-1.26.4 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.1.105 nvidia-nvtx-cu12-12.1.105 opencv-python-4.10.0.84 opt-einsum-3.3.0 optax-0.2.2 orbax-checkpoint-0.5.16 osqp-0.6.7.post0 packaging-24.0 pettingzoo-1.24.3 pillow-10.2.0 pin-2.7.0 platformdirs-4.2.2 portion-2.4.2 proto-plus-1.23.0 protobuf-4.25.3 proxsuite-0.6.6 psutil-5.9.8 pyarrow-16.1.0 pyasn1-0.6.0 pyasn1_modules-0.4.0 pybullet-3.2.6 pyparsing-3.1.2 python-dateutil-2.9.0.post0 qdldl-0.1.7.post4 qpth-0.0.17 regex-2024.5.15 requests-2.32.3 rich-13.7.1 rsa-4.9 safetensors-0.4.3 scikit-learn-1.5.2 scipy-1.13.1 scs-3.2.6 sentry-sdk-2.12.0 setproctitle-1.3.3 shellingham-1.5.4 six-1.16.0 smmap-5.0.1 sortedcontainers-2.4.0 sympy-1.12 tensorstore-0.1.62 threadpoolctl-3.5.0 tokenizers-0.19.1 tomli-2.4.0 toolz-0.12.1 torch-2.2.2 tqdm-4.66.4 transformers-4.41.2 triton-2.2.0 typer-0.12.3 typing_extensions-4.12.1 urllib3-2.2.1 wandb-0.17.5 zipp-3.19.1
# Offline wheelhouse install succeeded
# gurobipy 11.0.3 is not supported on this platform
# Only known non-fatal pip check warnings detected; continuing
# numpy: 1.26.4
# torch: 2.2.2+cu121
# cuda: True
# python: /content/miniconda3/envs/FMPCC/bin/python
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# WARNING: typer 0.12.3 does not provide the extra 'all'

# %% [markdown]
# ## 7) Runtime Environment Variables
#
# Includes W&B malformed service cleanup and Colab rendering settings.

# %%
import os

FMPCC = '/content/drive/MyDrive/FMPCC/FM-PCC'
D3IL_ROOT = f'{FMPCC}/d3il'
GYM_AV = f'{D3IL_ROOT}/environments/d3il/envs/gym_avoiding_env'

existing_pp = os.environ.get('PYTHONPATH', '')
parts = [FMPCC, D3IL_ROOT, GYM_AV]
if existing_pp:
    parts.append(existing_pp)

os.environ['FMPCC'] = FMPCC
os.environ['PYTHONPATH'] = ':'.join(parts)
os.environ['MUJOCO_GL'] = 'egl'
os.environ['PYOPENGL_PLATFORM'] = 'egl'
os.environ['MPLBACKEND'] = 'agg'

for key in ('WANDB_SERVICE', 'WANDB__SERVICE'):
    os.environ.pop(key, None)

os.chdir(FMPCC)
print('cwd:', os.getcwd())
print('PYTHONPATH:', os.environ['PYTHONPATH'])
# Out:
# cwd: /content/drive/MyDrive/FMPCC/FM-PCC
# PYTHONPATH: /content/drive/MyDrive/FMPCC/FM-PCC:/content/drive/MyDrive/FMPCC/FM-PCC/d3il:/content/drive/MyDrive/FMPCC/FM-PCC/d3il/environments/d3il/envs/gym_avoiding_env:/env/python

# %% [markdown]
# ## 8) Optional W&B Login

# %%
import os
from pathlib import Path
import wandb

KEY_FILE = Path('/content/drive/MyDrive/FMPCC/.wandb_api_key')

if not KEY_FILE.exists():
    raise FileNotFoundError(
        f'Missing W&B key file: {KEY_FILE}. Create it with your API key on one line.'
    )

api_key = KEY_FILE.read_text(encoding='utf-8').strip()
if not api_key:
    raise ValueError(f'W&B key file is empty: {KEY_FILE}')

for k in ('WANDB_SERVICE', 'WANDB__SERVICE'):
    os.environ.pop(k, None)

wandb.finish()
os.environ['WANDB_MODE'] = 'online'
os.environ['WANDB_API_KEY'] = api_key

wandb.login(key=api_key, relogin=True)

print('W&B mode:', os.environ.get('WANDB_MODE'))
print('W&B key file:', KEY_FILE)
print('W&B key loaded:', f'***{api_key[-4:]}' if len(api_key) >= 4 else '***')
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: [wandb.login()] Using explicit session credentials for https://api.wandb.ai.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: llmmail2021 (llmmail2021-technical-university-of-munich) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# W&B mode: online
# W&B key file: /content/drive/MyDrive/FMPCC/.wandb_api_key
# W&B key loaded: ***KogM

# %% [markdown]
# ## 9) Full Verification
#
# Validates import chain with the exact env interpreter used for training.

# %%
# %%bash
# set -e
#
# /content/miniconda3/envs/FMPCC/bin/python - <<'PY'
# import importlib
# import sys
#
# pkgs = [
#     'torch', 'numpy', 'scipy', 'gym', 'gymnasium', 'gymnasium_robotics',
#     'minari', 'wandb', 'mujoco', 'diffusers', 'transformers'
# ]
#
# ok = True
# for p in pkgs:
#     try:
#         m = importlib.import_module(p)
#         v = getattr(m, '__version__', 'unknown')
#         print(f'{p:20s} {v}')
#     except Exception as e:
#         ok = False
#         print(f'{p:20s} NOT IMPORTABLE ({type(e).__name__}: {e})')
#
# import numpy, torch
# print('numpy pinned:', numpy.__version__)
# print('cuda available:', torch.cuda.is_available())
# if torch.cuda.is_available():
#     print('device:', torch.cuda.get_device_name(0))
#
# major = int(numpy.__version__.split('.')[0])
# if major >= 2:
#     ok = False
#     print('ERROR: numpy 2.x detected, expected 1.26.4 for this workflow')
#
# if not ok:
#     sys.exit(2)
# PY
# Out:
# torch                2.2.2+cu121
# numpy                1.26.4
# scipy                1.13.1
# gym                  0.26.2
# gymnasium            0.29.1
# gymnasium_robotics   1.2.4
# minari               0.4.3
# wandb                0.17.5
# mujoco               2.3.7
# diffusers            0.31.0
# transformers         4.41.2
# numpy pinned: 1.26.4
# cuda available: True
# device: Tesla T4
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]

# %% [markdown]
# ## 10) Dataset Preparation (Avoiding)
#
# ### Option A: Use existing zip from old DPCC path
#
# Warning! : It searches the ~15Gb Zip in the DPCC Path, not this FMPCC Path!
#
#
# This exits quickly if avoiding data already exists.

# %%
# %%bash
# set -e
#
# REPO="/content/drive/MyDrive/FMPCC/FM-PCC"
# AVOIDING_DATA="$REPO/d3il/environments/dataset/data/avoiding/data"
# DATA_ZIP="/content/drive/MyDrive/DPCC/dpcc/d3il/environments/dataset/data/dataset.zip"
#
# if [ -d "$AVOIDING_DATA" ] && [ "$(ls -A "$AVOIDING_DATA")" ]; then
#   echo "avoiding data already present: $(ls "$AVOIDING_DATA" | wc -l) files"
#   exit 0
# fi
#
# if [ ! -f "$DATA_ZIP" ]; then
#   echo "dataset zip not found: $DATA_ZIP"
#   echo "Skip this cell and use Option B below if needed."
#   exit 1
# fi
#
# TMP="/content/avoiding_tmp"
# rm -rf "$TMP"
# mkdir -p "$TMP"
# unzip -q "$DATA_ZIP" "avoiding/*" -d "$TMP"
# mkdir -p "$REPO/d3il/environments/dataset/data/avoiding"
# cp -r "$TMP/avoiding/." "$REPO/d3il/environments/dataset/data/avoiding/"
# rm -rf "$TMP"
#
# echo "avoiding dataset ready: $(ls "$AVOIDING_DATA" | wc -l) files"

# %% [markdown]
# ### Option B: Download full D3IL dataset zip with gdown (only if Option A unavailable)

# %% [markdown]
# ```
# %%bash
# set -e
#
# REPO="/content/drive/MyDrive/FMPCC/FM-PCC"
# DATA_DIR="$REPO/d3il/environments/dataset/data"
# ZIP_FILE="$DATA_DIR/dataset.zip"
#
# if [ -f "$ZIP_FILE" ]; then
#   echo "zip already exists: $ZIP_FILE"
#   exit 0
# fi
#
# /content/miniconda3/envs/FMPCC/bin/pip install gdown -q
# /content/miniconda3/envs/FMPCC/bin/python -m gdown \
#   "https://drive.google.com/uc?id=1SQhbhzV85zf_ltnQ8Cbge2lsSWInxVa8" \
#   -O "$ZIP_FILE"
#
# echo "downloaded zip: $ZIP_FILE"

# %% [markdown]
# ## 11) Smoke Test Train
#
# Short check before full run.

# %% [markdown]
# # IN THIS TIME !!!
#
#
# seed 6 for projection_eval.yaml

# %% [markdown]
# ## 12) Full Train
#
# Real-time streaming via `!python`.

# %%
#!/content/miniconda3/envs/FMPCC/bin/python scripts/train.py --seeds 6 --num-seeds 1 --use-wandb --wandb-project FMPCC

# !/content/miniconda3/envs/FMPCC/bin/python FM_test/train_FM.py --seeds 7 --num-seeds 1 --use-wandb --wandb-project FMPCC

# %%
# !/content/miniconda3/envs/FMPCC/bin/python FM_v2_test/train_FM_v2.py --seeds 6 --num-seeds 1 --use-wandb --wandb-project FMPCC
# Out:
# [ train ] Seed source: cli --seeds
# [ train ] Training seeds: [6]
# [ utils/setup ] Made savepath: logs/avoiding-d3il/flow_matching_v2/H8_K20_Dmodels.diffusion.GaussianDiffusion/6
# [ train ] Saved seed manifest to: logs/avoiding-d3il/flow_matching_v2/H8_K20_Dmodels.diffusion.GaussianDiffusion/seeds_config.json
# wandb: Currently logged in as: llmmail2021 (llmmail2021-technical-university-of-munich). Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.25.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.17.5
# wandb: Run data is saved locally in /content/drive/MyDrive/FMPCC/FM-PCC/wandb/run-20260404_144151-hc7sve6m
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run avoiding-d3il-seed-6
# wandb: ⭐️ View project at https://wandb.ai/llmmail2021-technical-university-of-munich/FMPCC
# wandb: 🚀 View run at https://wandb.ai/llmmail2021-technical-university-of-munich/FMPCC/runs/hc7sve6m
#
# [utils/config ] Config: <class 'flow_matcher_v2.datasets.sequence.SequenceDataset'>
#     discount: 0.99
#     env: avoiding-d3il
#     horizon: 8
#     include_returns: True
#     max_path_length: 150
#     normalizer: LimitsNormalizer
#     preprocess_fns: []
#     returns_scale: 150
#     use_padding: True
#
# [ utils/config ] Saved config to: logs/avoiding-d3il/flow_matching_v2/H8_K20_Dmodels.diffusion.GaussianDiffusion/6/dataset_config.pkl
#
# [ utils/config ] Saved config to: logs/avoiding-d3il/flow_matching_v2/H8_K20_Dmodels.diffusion.GaussianDiffusion/6/dataset_config.json
#
# [ datasets/buffer ] Fields:
#     observations: (96, 150, 4)
#     actions: (96, 150, 2)
#     rewards: (96, 150, 1)
#     terminals: (96, 150, 1)
#     normed_observations: (96, 150, 4)
#     normed_actions: (96, 150, 2)
#
# [utils/config ] Config: <class 'flow_matcher_v2.models.unet1d_temporal_cond.Flow_matcher_U_Net_v2'>
#     cond_dim: 4
#     condition_dropout: 0.25
#     dim: 32
#     dim_mults: (1, 2, 4, 8)
#     horizon: 8
#     returns_condition: False
#     transition_dim: 6
#
# [ utils/config ] Saved config to: logs/avoiding-d3il/flow_matching_v2/H8_K20_Dmodels.diffusion.GaussianDiffusion/6/model_config.pkl
#
# [ utils/config ] Saved config to: logs/avoiding-d3il/flow_matching_v2/H8_K20_Dmodels.diffusion.GaussianDiffusion/6/model_config.json
#
#
# [utils/config ] Config: <class 'flow_matcher_v2.models.diffusion.GaussianDiffusion'>
#     action_dim: 2
#     action_weight: 1
#     clip_denoised: False
#     condition_guidance_w: 1.2
#     goal_dim: 0
#     horizon: 8
#     loss_discount: 1.0
#     loss_type: l2
#     n_timesteps: 20
#     observation_dim: 4
#     ode_inference_steps_v2: 10
#     predict_epsilon: True
#     returns_condition: False
#     time_beta_alpha_v2: 1.5
#     time_beta_beta_v2: 1.0
#     vf_time_bins_v2: 20
#
# [ utils/config ] Saved config to: logs/avoiding-d3il/flow_matching_v2/H8_K20_Dmodels.diffusion.GaussianDiffusion/6/diffusion_config.pkl
#
# [ utils/config ] Saved config to: logs/avoiding-d3il/flow_matching_v2/H8_K20_Dmodels.diffusion.GaussianDiffusion/6/diffusion_config.json
#
#
# [utils/config ] Config: <class 'flow_matcher_v2.utils.training.Trainer'>
#     ema_decay: 0.995
#     gradient_accumulate_every: 2
#     n_steps_per_epoch: 1000
#     n_train_steps: 100000.0
#     results_folder: logs/avoiding-d3il/flow_matching_v2/H8_K20_Dmodels.diffusion.GaussianDiffusion/6
#     train_batch_size: 8
#     train_lr: 0.0001
#     train_test_split: 0.9
#
# [ utils/config ] Saved config to: logs/avoiding-d3il/flow_matching_v2/H8_K20_Dmodels.diffusion.GaussianDiffusion/6/trainer_config.pkl
#
# [ utils/config ] Saved config to: logs/avoiding-d3il/flow_matching_v2/H8_K20_Dmodels.diffusion.GaussianDiffusion/6/trainer_config.json
#
# Epoch 0:   0% 0/1000 [00:00<?, ?it/s]Initial test loss:   0.6944, a0 loss:   1.4682
# Epoch 0: 100% 1000/1000 [01:31<00:00, 10.90it/s, a0_loss=1.41, a0_loss_test=1.47, diffusion_loss=0.86, loss=0.43, loss_test=0.694, lr=0.0001, step=999]
# Epoch 1: 100% 1000/1000 [01:22<00:00, 12.07it/s, a0_loss=0.433, a0_loss_test=1.21, diffusion_loss=0.353, loss=0.177, loss_test=0.361, lr=0.0001, step=1999]
# Epoch 2: 100% 1000/1000 [01:22<00:00, 12.08it/s, a0_loss=0.946, a0_loss_test=0.895, diffusion_loss=0.303, loss=0.152, loss_test=0.173, lr=9.99e-5, step=2999]
# Epoch 3: 100% 1000/1000 [01:22<00:00, 12.06it/s, a0_loss=0.638, a0_loss_test=0.711, diffusion_loss=0.14, loss=0.0702, loss_test=0.141, lr=9.98e-5, step=3999]
# Epoch 4: 100% 1000/1000 [01:22<00:00, 12.07it/s, a0_loss=0.384, a0_loss_test=0.684, diffusion_loss=0.183, loss=0.0915, loss_test=0.124, lr=9.96e-5, step=4999]
# Epoch 5: 100% 1000/1000 [01:23<00:00, 12.02it/s, a0_loss=0.458, a0_loss_test=0.549, diffusion_loss=0.209, loss=0.105, loss_test=0.109, lr=9.94e-5, step=5999]
# Epoch 6: 100% 1000/1000 [01:22<00:00, 12.05it/s, a0_loss=0.255, a0_loss_test=0.605, diffusion_loss=0.165, loss=0.0825, loss_test=0.106, lr=9.91e-5, step=6999]
# Epoch 7: 100% 1000/1000 [01:21<00:00, 12.31it/s, a0_loss=0.868, a0_loss_test=0.535, diffusion_loss=0.237, loss=0.118, loss_test=0.0946, lr=9.88e-5, step=7999]
# Epoch 8: 100% 1000/1000 [01:24<00:00, 11.88it/s, a0_loss=0.283, a0_loss_test=0.462, diffusion_loss=0.169, loss=0.0846, loss_test=0.0861, lr=9.84e-5, step=8999]
# Epoch 9: 100% 1000/1000 [01:22<00:00, 12.05it/s, a0_loss=0.303, a0_loss_test=0.48, diffusion_loss=0.156, loss=0.0781, loss_test=0.0872, lr=9.8e-5, step=9999]
# Epoch 10: 100% 1000/1000 [01:21<00:00, 12.31it/s, a0_loss=0.304, a0_loss_test=0.477, diffusion_loss=0.182, loss=0.0908, loss_test=0.0867, lr=9.75e-5, step=10999]
# Epoch 11: 100% 1000/1000 [01:21<00:00, 12.20it/s, a0_loss=0.619, a0_loss_test=0.462, diffusion_loss=0.172, loss=0.0862, loss_test=0.0823, lr=9.7e-5, step=11999]
# Epoch 12: 100% 1000/1000 [01:20<00:00, 12.49it/s, a0_loss=1.53, a0_loss_test=0.495, diffusion_loss=0.156, loss=0.0779, loss_test=0.0859, lr=9.64e-5, step=12999]
# Epoch 13: 100% 1000/1000 [01:22<00:00, 12.17it/s, a0_loss=0.261, a0_loss_test=0.439, diffusion_loss=0.16, loss=0.0802, loss_test=0.0819, lr=9.58e-5, step=13999]
# Epoch 14: 100% 1000/1000 [01:21<00:00, 12.32it/s, a0_loss=0.186, a0_loss_test=0.408, diffusion_loss=0.113, loss=0.0567, loss_test=0.0796, lr=9.51e-5, step=14999]
# Epoch 15: 100% 1000/1000 [01:20<00:00, 12.46it/s, a0_loss=0.506, a0_loss_test=0.43, diffusion_loss=0.199, loss=0.0993, loss_test=0.0765, lr=9.44e-5, step=15999]
# Epoch 16: 100% 1000/1000 [01:23<00:00, 12.04it/s, a0_loss=0.508, a0_loss_test=0.457, diffusion_loss=0.207, loss=0.104, loss_test=0.0757, lr=9.37e-5, step=16999]
# Epoch 17: 100% 1000/1000 [01:24<00:00, 11.77it/s, a0_loss=1.22, a0_loss_test=0.434, diffusion_loss=0.274, loss=0.137, loss_test=0.0754, lr=9.29e-5, step=17999]
# Epoch 18: 100% 1000/1000 [01:25<00:00, 11.73it/s, a0_loss=0.353, a0_loss_test=0.426, diffusion_loss=0.153, loss=0.0763, loss_test=0.0739, lr=9.21e-5, step=18999]
# Epoch 19: 100% 1000/1000 [01:25<00:00, 11.70it/s, a0_loss=0.805, a0_loss_test=0.417, diffusion_loss=0.262, loss=0.131, loss_test=0.0712, lr=9.12e-5, step=2e+4]
# Epoch 20: 100% 1000/1000 [01:25<00:00, 11.70it/s, a0_loss=0.409, a0_loss_test=0.37, diffusion_loss=0.182, loss=0.0909, loss_test=0.0716, lr=9.03e-5, step=20999]
# Epoch 21: 100% 1000/1000 [01:25<00:00, 11.71it/s, a0_loss=0.564, a0_loss_test=0.385, diffusion_loss=0.156, loss=0.0778, loss_test=0.0701, lr=8.93e-5, step=21999]
# Epoch 22: 100% 1000/1000 [01:21<00:00, 12.30it/s, a0_loss=0.36, a0_loss_test=0.399, diffusion_loss=0.196, loss=0.0981, loss_test=0.0725, lr=8.83e-5, step=22999]
# Epoch 23: 100% 1000/1000 [01:22<00:00, 12.10it/s, a0_loss=0.19, a0_loss_test=0.458, diffusion_loss=0.128, loss=0.0639, loss_test=0.0734, lr=8.73e-5, step=23999]
# Epoch 24: 100% 1000/1000 [01:22<00:00, 12.16it/s, a0_loss=0.606, a0_loss_test=0.369, diffusion_loss=0.107, loss=0.0537, loss_test=0.0698, lr=8.62e-5, step=24999]
# Epoch 25: 100% 1000/1000 [01:22<00:00, 12.08it/s, a0_loss=1.13, a0_loss_test=0.346, diffusion_loss=0.212, loss=0.106, loss_test=0.0644, lr=8.51e-5, step=25999]
# Epoch 26: 100% 1000/1000 [01:21<00:00, 12.21it/s, a0_loss=0.169, a0_loss_test=0.395, diffusion_loss=0.128, loss=0.0642, loss_test=0.0704, lr=8.39e-5, step=26999]
# Epoch 27: 100% 1000/1000 [01:21<00:00, 12.20it/s, a0_loss=0.832, a0_loss_test=0.388, diffusion_loss=0.113, loss=0.0567, loss_test=0.07, lr=8.27e-5, step=27999]
# Epoch 28: 100% 1000/1000 [01:20<00:00, 12.36it/s, a0_loss=0.192, a0_loss_test=0.329, diffusion_loss=0.0756, loss=0.0378, loss_test=0.0615, lr=8.15e-5, step=28999]
# Epoch 29: 100% 1000/1000 [01:20<00:00, 12.43it/s, a0_loss=0.266, a0_loss_test=0.418, diffusion_loss=0.132, loss=0.066, loss_test=0.0721, lr=8.03e-5, step=3e+4]
# Epoch 30: 100% 1000/1000 [01:18<00:00, 12.72it/s, a0_loss=0.41, a0_loss_test=0.362, diffusion_loss=0.107, loss=0.0535, loss_test=0.0624, lr=7.9e-5, step=30999]
# Epoch 31: 100% 1000/1000 [01:21<00:00, 12.23it/s, a0_loss=0.412, a0_loss_test=0.339, diffusion_loss=0.0511, loss=0.0255, loss_test=0.0597, lr=7.77e-5, step=31999]
# Epoch 32: 100% 1000/1000 [01:21<00:00, 12.26it/s, a0_loss=0.125, a0_loss_test=0.384, diffusion_loss=0.0845, loss=0.0423, loss_test=0.0624, lr=7.64e-5, step=32999]
# Epoch 33: 100% 1000/1000 [01:19<00:00, 12.66it/s, a0_loss=0.146, a0_loss_test=0.348, diffusion_loss=0.0544, loss=0.0272, loss_test=0.0628, lr=7.5e-5, step=33999]
# Epoch 34: 100% 1000/1000 [01:20<00:00, 12.38it/s, a0_loss=0.263, a0_loss_test=0.39, diffusion_loss=0.17, loss=0.0849, loss_test=0.0628, lr=7.36e-5, step=34999]
# Epoch 35: 100% 1000/1000 [01:19<00:00, 12.57it/s, a0_loss=0.144, a0_loss_test=0.364, diffusion_loss=0.129, loss=0.0643, loss_test=0.0657, lr=7.22e-5, step=35999]
# Epoch 36: 100% 1000/1000 [01:23<00:00, 12.00it/s, a0_loss=0.332, a0_loss_test=0.337, diffusion_loss=0.129, loss=0.0643, loss_test=0.0614, lr=7.08e-5, step=36999]
# Epoch 37: 100% 1000/1000 [01:21<00:00, 12.21it/s, a0_loss=0.821, a0_loss_test=0.335, diffusion_loss=0.282, loss=0.141, loss_test=0.0596, lr=6.93e-5, step=37999]
# Epoch 82: 100% 1000/1000 [01:21<00:00, 12.34it/s, a0_loss=0.049, a0_loss_test=0.27, diffusion_loss=0.0726, loss=0.0363, loss_test=0.0508, lr=7.1e-6, step=82999]
# Epoch 83: 100% 1000/1000 [01:19<00:00, 12.53it/s, a0_loss=0.293, a0_loss_test=0.28, diffusion_loss=0.0942, loss=0.0471, loss_test=0.0514, lr=6.31e-6, step=83999]
# Epoch 84: 100% 1000/1000 [01:19<00:00, 12.55it/s, a0_loss=0.167, a0_loss_test=0.266, diffusion_loss=0.0899, loss=0.045, loss_test=0.0472, lr=5.56e-6, step=84999]
# Epoch 85: 100% 1000/1000 [01:21<00:00, 12.22it/s, a0_loss=0.345, a0_loss_test=0.292, diffusion_loss=0.101, loss=0.0506, loss_test=0.0508, lr=4.85e-6, step=85999]
# Epoch 86: 100% 1000/1000 [01:18<00:00, 12.71it/s, a0_loss=0.345, a0_loss_test=0.241, diffusion_loss=0.13, loss=0.0648, loss_test=0.0462, lr=4.19e-6, step=86999]
# Epoch 87: 100% 1000/1000 [01:19<00:00, 12.53it/s, a0_loss=0.0831, a0_loss_test=0.265, diffusion_loss=0.0952, loss=0.0476, loss_test=0.0493, lr=3.58e-6, step=87999]
# Epoch 88: 100% 1000/1000 [01:18<00:00, 12.77it/s, a0_loss=0.247, a0_loss_test=0.272, diffusion_loss=0.0611, loss=0.0306, loss_test=0.0499, lr=3.02e-6, step=88999]
# Epoch 89: 100% 1000/1000 [01:24<00:00, 11.82it/s, a0_loss=0.359, a0_loss_test=0.275, diffusion_loss=0.0734, loss=0.0367, loss_test=0.0508, lr=2.5e-6, step=9e+4]
# Epoch 90: 100% 1000/1000 [01:19<00:00, 12.61it/s, a0_loss=0.174, a0_loss_test=0.24, diffusion_loss=0.201, loss=0.101, loss_test=0.044, lr=2.03e-6, step=90999]
# Epoch 91: 100% 1000/1000 [01:18<00:00, 12.82it/s, a0_loss=0.155, a0_loss_test=0.236, diffusion_loss=0.0531, loss=0.0266, loss_test=0.0477, lr=1.6e-6, step=91999]
# Epoch 92: 100% 1000/1000 [01:17<00:00, 12.90it/s, a0_loss=0.101, a0_loss_test=0.258, diffusion_loss=0.0893, loss=0.0446, loss_test=0.0493, lr=1.23e-6, step=92999]
# Epoch 93: 100% 1000/1000 [01:19<00:00, 12.56it/s, a0_loss=0.0911, a0_loss_test=0.242, diffusion_loss=0.066, loss=0.033, loss_test=0.0476, lr=9.04e-7, step=93999]
# Epoch 94: 100% 1000/1000 [01:19<00:00, 12.64it/s, a0_loss=0.182, a0_loss_test=0.252, diffusion_loss=0.0704, loss=0.0352, loss_test=0.0464, lr=6.28e-7, step=94999]
# Epoch 95: 100% 1000/1000 [01:20<00:00, 12.39it/s, a0_loss=0.0953, a0_loss_test=0.232, diffusion_loss=0.0397, loss=0.0199, loss_test=0.048, lr=4.02e-7, step=95999]
# Epoch 96: 100% 1000/1000 [01:18<00:00, 12.69it/s, a0_loss=0.201, a0_loss_test=0.242, diffusion_loss=0.087, loss=0.0435, loss_test=0.0467, lr=2.26e-7, step=96999]
# Epoch 97: 100% 1000/1000 [01:22<00:00, 12.18it/s, a0_loss=0.145, a0_loss_test=0.249, diffusion_loss=0.119, loss=0.0593, loss_test=0.0457, lr=1.01e-7, step=97999]
# Epoch 98: 100% 1000/1000 [01:23<00:00, 11.97it/s, a0_loss=0.111, a0_loss_test=0.214, diffusion_loss=0.105, loss=0.0523, loss_test=0.0445, lr=2.52e-8, step=98999]
# Epoch 99: 100% 1000/1000 [01:18<00:00, 12.72it/s, a0_loss=0.0756, a0_loss_test=0.274, diffusion_loss=0.0569, loss=0.0284, loss_test=0.0472, lr=0, step=1e+5]
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/FMPCC/FM-PCC/FM_v2_test/train_FM_v2.py", line 293, in <module>
#     upload_wandb_artifact(run, seed, args)
#   File "/content/drive/MyDrive/FMPCC/FM-PCC/FM_v2_test/train_FM_v2.py", line 62, in upload_wandb_artifact
#     artifact = run.Artifact(
# AttributeError: 'Run' object has no attribute 'Artifact'
# wandb:
# wandb: Run history:
# wandb:  test/a0_loss █▅▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:     test/loss █▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb: train/a0_loss █▆▃▂▂▂▁▂▂▂▂▂▂▂▁▂▂▂▁▃▁▂▂▁▂▁▁▁▂▁▁▁▂▁▁▁▁▂▁▂
# wandb:    train/loss █▃▃▂▃▂▁▁▂▁▁▂▁▁▁▂▂▁▁▂▂▁▁▁▂▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:  final_test_loss 0.04721
# wandb: final_train_loss 0.02793
# wandb:     test/a0_loss 0.27394
# wandb:        test/loss 0.04721
# wandb:    train/a0_loss 0.29282
# wandb:       train/loss 0.02793
# wandb:
# wandb: 🚀 View run avoiding-d3il-seed-6 at: https://wandb.ai/llmmail2021-technical-university-of-munich/FMPCC/runs/hc7sve6m
# wandb: ⭐️ View project at: https://wandb.ai/llmmail2021-technical-university-of-munich/FMPCC
# wandb: Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20260404_144151-hc7sve6m/logs
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.

# %% [markdown]
# ## 13) Resume Training (Optional)

# %%
#!/content/miniconda3/envs/FMPCC/bin/python scripts/train.py --seeds 5 --auto-resume --use-wandb --wandb-project FMPCC
# !/content/miniconda3/envs/FMPCC/bin/python FM_test/train_FM.py --seeds 7 --auto-resume --use-wandb --wandb-project FMPCC

# %% [markdown]
# ## 14) Evaluation and Results

# %% [markdown]
# Remember to edit the yaml in /config to choose seeds
# and
# must write_to_file: True

# %%
#!/content/miniconda3/envs/FMPCC/bin/python scripts/eval.py
# !/content/miniconda3/envs/FMPCC/bin/python FM_test/eval_FM.py

# %%
# !/content/miniconda3/envs/FMPCC/bin/python FM_v2_test/eval_FM_v2.py
# Out:
# pybullet build time: Nov 28 2023 23:45:17
# [ utils/setup ] Made savepath: logs/avoiding-d3il/plans/flow_matching_v2/H8_K20_Dmodels.diffusion.GaussianDiffusion/6
#
# [ utils/serialization ] Loading model from logs/avoiding-d3il/flow_matching_v2/H8_K20_Dmodels.diffusion.GaussianDiffusion/6
#
# [ datasets/buffer ] Fields:
#     observations: (96, 150, 4)
#     actions: (96, 150, 2)
#     rewards: (96, 150, 1)
#     terminals: (96, 150, 1)
#     normed_observations: (96, 150, 4)
#     normed_actions: (96, 150, 2)
# [ utils/training ] Restored loss history from checkpoint at step 90000
# WARNING: mju_openResource: could not open resource '/content/drive/MyDrive/FMPCC/FM-PCC/d3il/environments/d3il/models/mj/robot/panda_tmp_rb0_7890959c-3047-11f1-9e3c-0242ac1c000c.xml' with default provider at slot 1
#
# Final IK error (78 iterations):  7.2858622740627195e-06
# Final IK error (0 iterations):  7.2858622740627195e-06
# ------------------------Running avoiding-d3il - top-right-hard - dpcc-r (6)----------------------------
# Success rate: 0.0
# Constraints satisfied: 0.0
# Success rate (goal and constraints): 0.0
# Avg number of steps: 0.00 +- 0.00
# Avg number of constraint violations: 1.50 +- 1.50
# Avg total violation: 0.008 +- 0.008
# Average computation time per step: 0.226
# ------------------------Running avoiding-d3il - top-right-hard - dpcc-r-tightened (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 1.0
# Success rate (goal and constraints): 1.0
# Avg number of steps: 75.50 +- 12.50
# Avg number of constraint violations: 0.00 +- 0.00
# Avg total violation: 0.000 +- 0.000
# Average computation time per step: 0.287
# ------------------------Running avoiding-d3il - top-right-hard - dpcc-c (6)----------------------------
# Success rate: 0.5
# Constraints satisfied: 0.5
# Success rate (goal and constraints): 0.5
# Avg number of steps: 73.00 +- 0.00
# Avg number of constraint violations: 1.00 +- 1.00
# Avg total violation: 0.001 +- 0.001
# Average computation time per step: 0.240
# ------------------------Running avoiding-d3il - top-right-hard - dpcc-c-tightened (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 1.0
# Success rate (goal and constraints): 1.0
# Avg number of steps: 63.00 +- 7.00
# Avg number of constraint violations: 0.00 +- 0.00
# Avg total violation: 0.000 +- 0.000
# Average computation time per step: 0.242
# ------------------------Running avoiding-d3il - top-right-hard - dpcc-t (6)----------------------------
# Success rate: 0.5
# Constraints satisfied: 0.5
# Success rate (goal and constraints): 0.5
# Avg number of steps: 71.00 +- 0.00
# Avg number of constraint violations: 0.00 +- 0.00
# Avg total violation: 0.000 +- 0.000
# Average computation time per step: 0.236
# ------------------------Running avoiding-d3il - top-right-hard - dpcc-t-tightened (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 1.0
# Success rate (goal and constraints): 1.0
# Avg number of steps: 63.50 +- 9.50
# Avg number of constraint violations: 0.00 +- 0.00
# Avg total violation: 0.000 +- 0.000
# Average computation time per step: 0.278
# ------------------------Running avoiding-d3il - top-right-hard - diffuser (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 0.0
# Success rate (goal and constraints): 0.0
# Avg number of steps: 65.50 +- 8.50
# Avg number of constraint violations: 33.00 +- 1.00
# Avg total violation: 10.682 +- 0.010
# Average computation time per step: 0.168
# Tracking error: 0.029
# ------------------------Running avoiding-d3il - top-right-hard - gradient (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 0.0
# Success rate (goal and constraints): 0.0
# Avg number of steps: 66.50 +- 7.50
# Avg number of constraint violations: 34.00 +- 2.00
# Avg total violation: 7.776 +- 2.344
# Average computation time per step: 0.173
# ------------------------Running avoiding-d3il - top-right-hard - gradient-tightened (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 0.0
# Success rate (goal and constraints): 0.0
# Avg number of steps: 66.50 +- 7.50
# Avg number of constraint violations: 34.00 +- 2.00
# Avg total violation: 7.560 +- 2.399
# Average computation time per step: 0.175
# ------------------------Running avoiding-d3il - top-right-hard - post_processing (6)----------------------------
# Success rate: 0.0
# Constraints satisfied: 0.0
# Success rate (goal and constraints): 0.0
# Avg number of steps: 0.00 +- 0.00
# Avg number of constraint violations: 1.50 +- 1.50
# Avg total violation: 0.008 +- 0.008
# Average computation time per step: 0.227
# ------------------------Running avoiding-d3il - top-right-hard - post_processing-tightened (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 1.0
# Success rate (goal and constraints): 1.0
# Avg number of steps: 75.50 +- 12.50
# Avg number of constraint violations: 0.00 +- 0.00
# Avg total violation: 0.000 +- 0.000
# Average computation time per step: 0.327
# ------------------------Running avoiding-d3il - top-right-hard - model_free (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 0.0
# Success rate (goal and constraints): 0.0
# Avg number of steps: 68.00 +- 8.00
# Avg number of constraint violations: 35.50 +- 1.50
# Avg total violation: 7.743 +- 2.693
# Average computation time per step: 0.225
# ------------------------Running avoiding-d3il - top-right-hard - model_free-tightened (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 0.0
# Success rate (goal and constraints): 0.0
# Avg number of steps: 68.50 +- 7.50
# Avg number of constraint violations: 36.00 +- 2.00
# Avg total violation: 7.332 +- 2.428
# Average computation time per step: 0.232
# ------------------------Running avoiding-d3il - top-right-hard - dpcc-c-tightened-dt0p25 (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 0.5
# Success rate (goal and constraints): 0.5
# Avg number of steps: 90.50 +- 12.50
# Avg number of constraint violations: 1.00 +- 1.00
# Avg total violation: 0.003 +- 0.003
# Average computation time per step: 0.453
# ------------------------Running avoiding-d3il - top-right-hard - dpcc-c-tightened-dt0p5 (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 1.0
# Success rate (goal and constraints): 1.0
# Avg number of steps: 72.00 +- 11.00
# Avg number of constraint violations: 0.00 +- 0.00
# Avg total violation: 0.000 +- 0.000
# Average computation time per step: 0.274
# ------------------------Running avoiding-d3il - top-right-hard - dpcc-c-tightened-dt2p0 (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 1.0
# Success rate (goal and constraints): 1.0
# Avg number of steps: 72.50 +- 0.50
# Avg number of constraint violations: 0.00 +- 0.00
# Avg total violation: 0.000 +- 0.000
# Average computation time per step: 0.247
# ------------------------Running avoiding-d3il - top-right-hard - dpcc-c-tightened-dt4p0 (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 1.0
# Success rate (goal and constraints): 1.0
# Avg number of steps: 142.00 +- 4.00
# Avg number of constraint violations: 0.00 +- 0.00
# Avg total violation: 0.000 +- 0.000
# Average computation time per step: 0.268
# /content/drive/MyDrive/FMPCC/FM-PCC/FM_v2_test/eval_FM_v2.py:46: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   figs_all_seeds, axes_all_seeds = zip(*[plt.subplots(1, 1, figsize=(9, 10)) for _ in range(len(projection_variants))])
#
# [ utils/serialization ] Loading model from logs/avoiding-d3il/flow_matching_v2/H8_K20_Dmodels.diffusion.GaussianDiffusion/6
#
# [ datasets/buffer ] Fields:
#     observations: (96, 150, 4)
#     actions: (96, 150, 2)
#     rewards: (96, 150, 1)
#     terminals: (96, 150, 1)
#     normed_observations: (96, 150, 4)
#     normed_actions: (96, 150, 2)
# [ utils/training ] Restored loss history from checkpoint at step 90000
# WARNING: mju_openResource: could not open resource '/content/drive/MyDrive/FMPCC/FM-PCC/d3il/environments/d3il/models/mj/robot/panda_tmp_rb1_a57c80c8-3049-11f1-9e3c-0242ac1c000c.xml' with default provider at slot 1
#
# Final IK error (78 iterations):  7.2858622740627195e-06
# Final IK error (0 iterations):  7.2858622740627195e-06
# ------------------------Running avoiding-d3il - top-left-hard - dpcc-r (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 0.5
# Success rate (goal and constraints): 0.5
# Avg number of steps: 74.00 +- 18.00
# Avg number of constraint violations: 0.50 +- 0.50
# Avg total violation: 0.000 +- 0.000
# Average computation time per step: 0.305
# ------------------------Running avoiding-d3il - top-left-hard - dpcc-r-tightened (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 1.0
# Success rate (goal and constraints): 1.0
# Avg number of steps: 77.50 +- 13.50
# Avg number of constraint violations: 0.00 +- 0.00
# Avg total violation: 0.000 +- 0.000
# Average computation time per step: 0.375
# ------------------------Running avoiding-d3il - top-left-hard - dpcc-c (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 1.0
# Success rate (goal and constraints): 1.0
# Avg number of steps: 63.50 +- 6.50
# Avg number of constraint violations: 0.00 +- 0.00
# Avg total violation: 0.000 +- 0.000
# Average computation time per step: 0.335
# ------------------------Running avoiding-d3il - top-left-hard - dpcc-c-tightened (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 1.0
# Success rate (goal and constraints): 1.0
# Avg number of steps: 67.00 +- 7.00
# Avg number of constraint violations: 0.00 +- 0.00
# Avg total violation: 0.000 +- 0.000
# Average computation time per step: 0.347
# ------------------------Running avoiding-d3il - top-left-hard - dpcc-t (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 1.0
# Success rate (goal and constraints): 1.0
# Avg number of steps: 66.00 +- 8.00
# Avg number of constraint violations: 0.00 +- 0.00
# Avg total violation: 0.000 +- 0.000
# Average computation time per step: 0.254
# ------------------------Running avoiding-d3il - top-left-hard - dpcc-t-tightened (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 1.0
# Success rate (goal and constraints): 1.0
# Avg number of steps: 65.50 +- 7.50
# Avg number of constraint violations: 0.00 +- 0.00
# Avg total violation: 0.000 +- 0.000
# Average computation time per step: 0.283
# ------------------------Running avoiding-d3il - top-left-hard - diffuser (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 0.0
# Success rate (goal and constraints): 0.0
# Avg number of steps: 65.50 +- 8.50
# Avg number of constraint violations: 10.00 +- 1.00
# Avg total violation: 0.181 +- 0.022
# Average computation time per step: 0.166
# Tracking error: 0.029
# ------------------------Running avoiding-d3il - top-left-hard - gradient (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 0.0
# Success rate (goal and constraints): 0.0
# Avg number of steps: 65.50 +- 8.50
# Avg number of constraint violations: 10.00 +- 1.00
# Avg total violation: 0.165 +- 0.018
# Average computation time per step: 0.177
# ------------------------Running avoiding-d3il - top-left-hard - gradient-tightened (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 0.0
# Success rate (goal and constraints): 0.0
# Avg number of steps: 65.50 +- 8.50
# Avg number of constraint violations: 10.00 +- 1.00
# Avg total violation: 0.162 +- 0.021
# Average computation time per step: 0.181
# ------------------------Running avoiding-d3il - top-left-hard - post_processing (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 0.5
# Success rate (goal and constraints): 0.5
# Avg number of steps: 74.00 +- 18.00
# Avg number of constraint violations: 0.50 +- 0.50
# Avg total violation: 0.000 +- 0.000
# Average computation time per step: 0.290
# ------------------------Running avoiding-d3il - top-left-hard - post_processing-tightened (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 1.0
# Success rate (goal and constraints): 1.0
# Avg number of steps: 77.50 +- 13.50
# Avg number of constraint violations: 0.00 +- 0.00
# Avg total violation: 0.000 +- 0.000
# Average computation time per step: 0.367
# ------------------------Running avoiding-d3il - top-left-hard - model_free (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 0.0
# Success rate (goal and constraints): 0.0
# Avg number of steps: 66.50 +- 8.50
# Avg number of constraint violations: 10.00 +- 1.00
# Avg total violation: 0.146 +- 0.026
# Average computation time per step: 0.240
# ------------------------Running avoiding-d3il - top-left-hard - model_free-tightened (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 0.0
# Success rate (goal and constraints): 0.0
# Avg number of steps: 66.00 +- 9.00
# Avg number of constraint violations: 10.00 +- 1.00
# Avg total violation: 0.143 +- 0.028
# Average computation time per step: 0.241
# ------------------------Running avoiding-d3il - top-left-hard - dpcc-c-tightened-dt0p25 (6)----------------------------
# /content/miniconda3/envs/FMPCC/lib/python3.10/site-packages/scipy/optimize/_slsqp_py.py:437: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   fx = wrapped_fun(x)
# Success rate: 1.0
# Constraints satisfied: 0.5
# Success rate (goal and constraints): 0.5
# Avg number of steps: 137.50 +- 37.50
# Avg number of constraint violations: 51.50 +- 51.50
# Avg total violation: 0.840 +- 0.840
# Average computation time per step: 2.627
# ------------------------Running avoiding-d3il - top-left-hard - dpcc-c-tightened-dt0p5 (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 1.0
# Success rate (goal and constraints): 1.0
# Avg number of steps: 76.00 +- 9.00
# Avg number of constraint violations: 0.00 +- 0.00
# Avg total violation: 0.001 +- 0.000
# Average computation time per step: 0.517
# ------------------------Running avoiding-d3il - top-left-hard - dpcc-c-tightened-dt2p0 (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 1.0
# Success rate (goal and constraints): 1.0
# Avg number of steps: 69.50 +- 3.50
# Avg number of constraint violations: 0.00 +- 0.00
# Avg total violation: 0.000 +- 0.000
# Average computation time per step: 0.259
# ------------------------Running avoiding-d3il - top-left-hard - dpcc-c-tightened-dt4p0 (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 1.0
# Success rate (goal and constraints): 1.0
# Avg number of steps: 142.50 +- 8.50
# Avg number of constraint violations: 0.00 +- 0.00
# Avg total violation: 0.000 +- 0.000
# Average computation time per step: 0.246
#
# [ utils/serialization ] Loading model from logs/avoiding-d3il/flow_matching_v2/H8_K20_Dmodels.diffusion.GaussianDiffusion/6
#
# [ datasets/buffer ] Fields:
#     observations: (96, 150, 4)
#     actions: (96, 150, 2)
#     rewards: (96, 150, 1)
#     terminals: (96, 150, 1)
#     normed_observations: (96, 150, 4)
#     normed_actions: (96, 150, 2)
# [ utils/training ] Restored loss history from checkpoint at step 90000
# WARNING: mju_openResource: could not open resource '/content/drive/MyDrive/FMPCC/FM-PCC/d3il/environments/d3il/models/mj/robot/panda_tmp_rb2_21d868e0-304e-11f1-9e3c-0242ac1c000c.xml' with default provider at slot 1
#
# Final IK error (78 iterations):  7.2858622740627195e-06
# Final IK error (0 iterations):  7.2858622740627195e-06
# ------------------------Running avoiding-d3il - both-hard - dpcc-r (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 0.5
# Success rate (goal and constraints): 0.5
# Avg number of steps: 97.50 +- 34.50
# Avg number of constraint violations: 36.50 +- 36.50
# Avg total violation: 0.388 +- 0.388
# Average computation time per step: 0.304
# ------------------------Running avoiding-d3il - both-hard - dpcc-r-tightened (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 1.0
# Success rate (goal and constraints): 1.0
# Avg number of steps: 62.00 +- 2.00
# Avg number of constraint violations: 0.00 +- 0.00
# Avg total violation: 0.000 +- 0.000
# Average computation time per step: 0.346
# ------------------------Running avoiding-d3il - both-hard - dpcc-c (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 1.0
# Success rate (goal and constraints): 1.0
# Avg number of steps: 61.50 +- 1.50
# Avg number of constraint violations: 0.00 +- 0.00
# Avg total violation: 0.000 +- 0.000
# Average computation time per step: 0.332
# ------------------------Running avoiding-d3il - both-hard - dpcc-c-tightened (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 1.0
# Success rate (goal and constraints): 1.0
# Avg number of steps: 61.50 +- 4.50
# Avg number of constraint violations: 0.00 +- 0.00
# Avg total violation: 0.000 +- 0.000
# Average computation time per step: 0.392
# ------------------------Running avoiding-d3il - both-hard - dpcc-t (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 0.0
# Success rate (goal and constraints): 0.0
# Avg number of steps: 103.00 +- 44.00
# Avg number of constraint violations: 35.50 +- 32.50
# Avg total violation: 0.294 +- 0.283
# Average computation time per step: 0.318
# ------------------------Running avoiding-d3il - both-hard - dpcc-t-tightened (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 1.0
# Success rate (goal and constraints): 1.0
# Avg number of steps: 57.00 +- 1.00
# Avg number of constraint violations: 0.00 +- 0.00
# Avg total violation: 0.000 +- 0.000
# Average computation time per step: 0.313
# ------------------------Running avoiding-d3il - both-hard - diffuser (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 0.0
# Success rate (goal and constraints): 0.0
# Avg number of steps: 65.50 +- 8.50
# Avg number of constraint violations: 11.50 +- 0.50
# Avg total violation: 3.013 +- 0.172
# Average computation time per step: 0.167
# Tracking error: 0.029
# ------------------------Running avoiding-d3il - both-hard - gradient (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 0.0
# Success rate (goal and constraints): 0.0
# Avg number of steps: 65.50 +- 8.50
# Avg number of constraint violations: 11.50 +- 0.50
# Avg total violation: 2.804 +- 0.074
# Average computation time per step: 0.181
# ------------------------Running avoiding-d3il - both-hard - gradient-tightened (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 0.0
# Success rate (goal and constraints): 0.0
# Avg number of steps: 65.50 +- 8.50
# Avg number of constraint violations: 12.00 +- 1.00
# Avg total violation: 2.844 +- 0.109
# Average computation time per step: 0.174
# ------------------------Running avoiding-d3il - both-hard - post_processing (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 0.5
# Success rate (goal and constraints): 0.5
# Avg number of steps: 97.50 +- 34.50
# Avg number of constraint violations: 36.50 +- 36.50
# Avg total violation: 0.388 +- 0.388
# Average computation time per step: 0.295
# ------------------------Running avoiding-d3il - both-hard - post_processing-tightened (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 1.0
# Success rate (goal and constraints): 1.0
# Avg number of steps: 62.00 +- 2.00
# Avg number of constraint violations: 0.00 +- 0.00
# Avg total violation: 0.000 +- 0.000
# Average computation time per step: 0.344
# ------------------------Running avoiding-d3il - both-hard - model_free (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 0.5
# Success rate (goal and constraints): 0.5
# Avg number of steps: 66.50 +- 8.50
# Avg number of constraint violations: 6.00 +- 6.00
# Avg total violation: 1.445 +- 1.445
# Average computation time per step: 0.228
# ------------------------Running avoiding-d3il - both-hard - model_free-tightened (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 0.5
# Success rate (goal and constraints): 0.5
# Avg number of steps: 66.50 +- 8.50
# Avg number of constraint violations: 6.00 +- 6.00
# Avg total violation: 1.430 +- 1.430
# Average computation time per step: 0.240
# ------------------------Running avoiding-d3il - both-hard - dpcc-c-tightened-dt0p25 (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 1.0
# Success rate (goal and constraints): 1.0
# Avg number of steps: 71.50 +- 3.50
# Avg number of constraint violations: 0.00 +- 0.00
# Avg total violation: 0.000 +- 0.000
# Average computation time per step: 0.559
# ------------------------Running avoiding-d3il - both-hard - dpcc-c-tightened-dt0p5 (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 1.0
# Success rate (goal and constraints): 1.0
# Avg number of steps: 60.50 +- 5.50
# Avg number of constraint violations: 0.00 +- 0.00
# Avg total violation: 0.000 +- 0.000
# Average computation time per step: 0.548
# ------------------------Running avoiding-d3il - both-hard - dpcc-c-tightened-dt2p0 (6)----------------------------
# Success rate: 1.0
# Constraints satisfied: 1.0
# Success rate (goal and constraints): 1.0
# Avg number of steps: 72.00 +- 14.00
# Avg number of constraint violations: 0.00 +- 0.00
# Avg total violation: 0.000 +- 0.000
# Average computation time per step: 0.316
# ------------------------Running avoiding-d3il - both-hard - dpcc-c-tightened-dt4p0 (6)----------------------------

# %% [markdown]
# ### Load Results
#
# If the process crashed change the yaml to resume at crash point.
#
# Example Save Path : `logs/avoiding-d3il/plans/H8_K20_Dmodels.GaussianDiffusion/0/results/`

# %%
# !/content/miniconda3/envs/FMPCC/bin/python FM_test/load_results_FM.py

# %%
# !/content/miniconda3/envs/FMPCC/bin/python FM_v2_test/load_results_FM_v2.py

# %% [markdown]
# ## 15) Visualization

# %%
# !/content/miniconda3/envs/FMPCC/bin/python scripts/visualize_data_constraints.py

# %% [markdown]
# ## 16) Archive Logs to Drive

# %%
# %%bash
# set -e
#
# REPO="/content/drive/MyDrive/FMPCC/FM-PCC"
# STAMP="$(date +%Y%m%d_%H%M%S)"
# OUT="/content/drive/MyDrive/FMPCC/runs_snapshot/$STAMP"
#
# mkdir -p "$OUT"
# if [ -d "$REPO/logs" ]; then
#   cp -r "$REPO/logs" "$OUT/"
# fi
# if [ -d "$REPO/wandb" ]; then
#   cp -r "$REPO/wandb" "$OUT/"
# fi
#
# echo "snapshot saved: $OUT"

# %% [markdown]
# # misc

# %% [markdown]
# ## Load the Training Results (NOT USING CONDA)

# %% [markdown]
# ```
# # ============================================================
# # WHAT WE ARE PLOTTING (4 curves across 2 subplots):
# #
# #   Left subplot — "Total Loss":
# #     ✅ training_losses  (pkl col "training_losses"  + wandb "loss")
# #     ✅ test_losses       (pkl col "test_losses"      + wandb "loss_test")
# #
# #   Right subplot — "a0 Loss (Action Prediction)":
# #     ✅ training_a0_losses (pkl col "training_a0_losses" + wandb "a0_loss")
# #     ✅ test_a0_losses     (pkl col "test_a0_losses"     + wandb "a0_loss_test")
# #
# # WHAT WE ARE NOT PLOTTING:
# #     ❌ diffusion_loss       (available in wandb log, not plotted)
# #     ❌ diffusion_loss_test   (available in wandb log, not plotted)
# #     ❌ lr (learning rate)    (available in wandb log, not plotted)
# #
# # DATA SOURCES:
# #     - losses.pkl  → late training data (~step 40000+)
# #     - WANDB_LOG_TEXT (hardcoded console paste) → epochs 0-72, steps 999-72193
# #     - combine() only adds wandb steps NOT already in pkl
# # ============================================================

# %% [markdown]
# FM

# %%
import os
import pickle
import numpy as np
import matplotlib.pyplot as plt

# ── Fallback Unpickler ──
class FallbackUnpickler(pickle.Unpickler):
    def find_class(self, module, name):
        if 'flow_matcher' in module:
            return type(name, (), {})
        return super().find_class(module, name)

# ── Target directory ──
target_dir = '/content/drive/MyDrive/FMPCC/FM-PCC/logs/avoiding-d3il/flow_matching/H8_K20_Dmodels.diffusion.GaussianDiffusion/6'

path_parts = target_dir.rstrip('/').split('/')
identifier = '__'.join(path_parts[3:]).replace('Dmodels.diffusion.', '').replace('.', '_')
print(f"Run identifier: {identifier}\n")

all_files = [
    f for f in os.listdir(target_dir)
    if os.path.isfile(os.path.join(target_dir, f)) and ':' not in f
]

print(f"Found {len(all_files)} files in: {target_dir}\n")

for file_name in all_files:
    path = os.path.join(target_dir, file_name)
    print(f"{'='*30} FILE: {file_name} {'='*30}")

    try:
        # Handle NumPy Archive (.npz)
        if file_name.endswith('.npz'):
            with np.load(path, allow_pickle=True) as data:
                for key in data.files:
                    arr = data[key]
                    print(f"Key: {key:<20} | Shape: {str(arr.shape):<12} | Dtype: {arr.dtype}")
                    if arr.size > 0:
                        print(arr if arr.size < 10 else f"First 5: {arr.flatten()[:5]}...")

        # Handle Pickle Files (.pkl) — always use FallbackUnpickler
        elif file_name.endswith('.pkl'):
            with open(path, 'rb') as f:
                content = FallbackUnpickler(f).load()

            if isinstance(content, dict):
                for k, v in content.items():
                    print(f"{k:<25}: {v}")
            elif hasattr(content, '__dict__'):
                print(f"  Type: {type(content).__name__}")
                for k, v in vars(content).items():
                    print(f"  {k}: {v}")
            elif isinstance(content, (list, np.ndarray)):
                arr_content = np.array(content)
                print(f"Data Type: {type(content)} | Length: {len(arr_content)}")
                print(f"Last Values: {arr_content[-5:]}")
            else:
                print(content)

            # ── Plot loss curves if this is losses.pkl ──
            if file_name == 'losses.pkl' and isinstance(content, dict):
                fig, axes = plt.subplots(1, 2, figsize=(14, 5))

                for key, label, color in [
                    ('training_losses', 'Training Loss', 'tab:blue'),
                    ('test_losses', 'Test Loss', 'tab:orange'),
                ]:
                    if key in content:
                        data = np.array(content[key])
                        axes[0].plot(data[:, 0], data[:, 1], label=label, color=color, alpha=0.8)
                axes[0].set_xlabel('Step')
                axes[0].set_ylabel('Loss')
                axes[0].set_title('Total Loss')
                axes[0].legend()
                axes[0].grid(True, alpha=0.3)

                for key, label, color in [
                    ('training_a0_losses', 'Training a0 Loss', 'tab:blue'),
                    ('test_a0_losses', 'Test a0 Loss', 'tab:orange'),
                ]:
                    if key in content:
                        data = np.array(content[key])
                        axes[1].plot(data[:, 0], data[:, 1], label=label, color=color, alpha=0.8)
                axes[1].set_xlabel('Step')
                axes[1].set_ylabel('Loss')
                axes[1].set_title('a0 Loss (Action Prediction)')
                axes[1].legend()
                axes[1].grid(True, alpha=0.3)

                plt.suptitle(f'Training — {identifier}', fontsize=13, fontweight='bold')
                plt.tight_layout()

                save_name = f'{identifier}__loss_curves.png'
                save_path = os.path.join(target_dir, save_name)
                plt.savefig(save_path, dpi=150)
                plt.show()
                print(f"\n✅ Loss curves saved to {save_path}")

        # Handle PyTorch Weights (.pt)
        elif file_name.endswith('.pt'):
            import torch
            checkpoint = torch.load(path, map_location='cpu')
            if isinstance(checkpoint, dict):
                print(f"Keys in Checkpoint: {list(checkpoint.keys())}")
            else:
                print("Raw Tensor/Object loaded.")

    except Exception as e:
        print(f"FAILED TO LOAD {file_name}: {e}")

    print("-" * 80)

# %% [markdown]
# DPCC

# %%
import os
import pickle
import numpy as np
import matplotlib.pyplot as plt

# ── Fallback Unpickler ──
class FallbackUnpickler(pickle.Unpickler):
    def find_class(self, module, name):
        if 'flow_matcher' in module:
            return type(name, (), {})
        return super().find_class(module, name)

# ── Target directory ──
target_dir = '/content/drive/MyDrive/FMPCC/FM-PCC/logs/avoiding-d3il/diffusion/H8_K20_Dmodels.GaussianDiffusion/5'

path_parts = target_dir.rstrip('/').split('/')
identifier = '__'.join(path_parts[3:]).replace('Dmodels.diffusion.', '').replace('.', '_')
print(f"Run identifier: {identifier}\n")

all_files = [
    f for f in os.listdir(target_dir)
    if os.path.isfile(os.path.join(target_dir, f)) and ':' not in f
]

print(f"Found {len(all_files)} files in: {target_dir}\n")

for file_name in all_files:
    path = os.path.join(target_dir, file_name)
    print(f"{'='*30} FILE: {file_name} {'='*30}")

    try:
        # Handle NumPy Archive (.npz)
        if file_name.endswith('.npz'):
            with np.load(path, allow_pickle=True) as data:
                for key in data.files:
                    arr = data[key]
                    print(f"Key: {key:<20} | Shape: {str(arr.shape):<12} | Dtype: {arr.dtype}")
                    if arr.size > 0:
                        print(arr if arr.size < 10 else f"First 5: {arr.flatten()[:5]}...")

        # Handle Pickle Files (.pkl) — always use FallbackUnpickler
        elif file_name.endswith('.pkl'):
            with open(path, 'rb') as f:
                content = FallbackUnpickler(f).load()

            if isinstance(content, dict):
                for k, v in content.items():
                    print(f"{k:<25}: {v}")
            elif hasattr(content, '__dict__'):
                print(f"  Type: {type(content).__name__}")
                for k, v in vars(content).items():
                    print(f"  {k}: {v}")
            elif isinstance(content, (list, np.ndarray)):
                arr_content = np.array(content)
                print(f"Data Type: {type(content)} | Length: {len(arr_content)}")
                print(f"Last Values: {arr_content[-5:]}")
            else:
                print(content)

            # ── Plot loss curves if this is losses.pkl ──
            if file_name == 'losses.pkl' and isinstance(content, dict):
                fig, axes = plt.subplots(1, 2, figsize=(14, 5))

                for key, label, color in [
                    ('training_losses', 'Training Loss', 'tab:blue'),
                    ('test_losses', 'Test Loss', 'tab:orange'),
                ]:
                    if key in content:
                        data = np.array(content[key])
                        axes[0].plot(data[:, 0], data[:, 1], label=label, color=color, alpha=0.8)
                axes[0].set_xlabel('Step')
                axes[0].set_ylabel('Loss')
                axes[0].set_title('Total Loss')
                axes[0].legend()
                axes[0].grid(True, alpha=0.3)

                for key, label, color in [
                    ('training_a0_losses', 'Training a0 Loss', 'tab:blue'),
                    ('test_a0_losses', 'Test a0 Loss', 'tab:orange'),
                ]:
                    if key in content:
                        data = np.array(content[key])
                        axes[1].plot(data[:, 0], data[:, 1], label=label, color=color, alpha=0.8)
                axes[1].set_xlabel('Step')
                axes[1].set_ylabel('Loss')
                axes[1].set_title('a0 Loss (Action Prediction)')
                axes[1].legend()
                axes[1].grid(True, alpha=0.3)

                plt.suptitle(f'Training — {identifier}', fontsize=13, fontweight='bold')
                plt.tight_layout()

                save_name = f'{identifier}__loss_curves.png'
                save_path = os.path.join(target_dir, save_name)
                plt.savefig(save_path, dpi=150)
                plt.show()
                print(f"\n✅ Loss curves saved to {save_path}")

        # Handle PyTorch Weights (.pt)
        elif file_name.endswith('.pt'):
            import torch
            checkpoint = torch.load(path, map_location='cpu')
            if isinstance(checkpoint, dict):
                print(f"Keys in Checkpoint: {list(checkpoint.keys())}")
            else:
                print("Raw Tensor/Object loaded.")

    except Exception as e:
        print(f"FAILED TO LOAD {file_name}: {e}")

    print("-" * 80)

# %% [markdown]
# ## Load with train data pkl, and print into output

# %%
import pickle

pkl_path = '/content/drive/MyDrive/FMPCC/FM-PCC/logs/avoiding-d3il/flow_matching_v2/H8_K20_Dmodels.diffusion.GaussianDiffusion/6/losses.pkl'

with open(pkl_path, 'rb') as f:
    data = pickle.load(f)

data_fm_v2 = data
data_fm_v2['_label'] = 'FM_v2'
data_fm_v2
# Out:
# {'training_losses': [[0, 0.6000020503997803],
#   [1000, 0.3169940114021301],
#   [2000, 0.20966678857803345],
#   [3000, 0.13078635931015015],
#   [4000, 0.11068522930145264],
#   [5000, 0.16292136907577515],
#   [6000, 0.045611463487148285],
#   [7000, 0.0736829861998558],
#   [8000, 0.06923489272594452],
#   [9000, 0.05649816617369652],
#   [10000, 0.17087183892726898],
#   [11000, 0.06262077391147614],
#   [12000, 0.08648756146430969],
#   [13000, 0.02461428940296173],
#   [14000, 0.08697327226400375],
#   [15000, 0.0389060378074646],
#   [16000, 0.048796337097883224],
#   [17000, 0.05574839562177658],
#   [18000, 0.11335259675979614],
#   [19000, 0.14952272176742554],
#   [20000, 0.09464859962463379],
#   [21000, 0.06605567038059235],
#   [22000, 0.03746573254466057],
#   [23000, 0.0572354793548584],
#   [24000, 0.03596871346235275],
#   [25000, 0.04814598709344864],
#   [26000, 0.03271143138408661],
#   [27000, 0.08547624200582504],
#   [28000, 0.04451186954975128],
#   [29000, 0.26279085874557495],
#   [30000, 0.04899664968252182],
#   [31000, 0.09584265947341919],
#   [32000, 0.0714540109038353],
#   [33000, 0.037387825548648834],
#   [34000, 0.039975039660930634],
#   [35000, 0.057594530284404755],
#   [36000, 0.07469320297241211],
#   [37000, 0.03406703099608421],
#   [38000, 0.06161792203783989],
#   [39000, 0.05191599577665329],
#   [40000, 0.06429082155227661],
#   [41000, 0.03299875557422638],
#   [42000, 0.08150868117809296],
#   [43000, 0.057685814797878265],
#   [44000, 0.05150604248046875],
#   [45000, 0.03284604847431183],
#   [46000, 0.0684933215379715],
#   [47000, 0.06965865194797516],
#   [48000, 0.09508761763572693],
#   [49000, 0.07387899607419968],
#   [50000, 0.08015485107898712],
#   [51000, 0.07466143369674683],
#   [52000, 0.04593018442392349],
#   [53000, 0.05189071223139763],
#   [54000, 0.046462517231702805],
#   [55000, 0.03634394705295563],
#   [56000, 0.06770118325948715],
#   [57000, 0.04785274714231491],
#   [58000, 0.021772276610136032],
#   [59000, 0.13195501267910004],
#   [60000, 0.10975416004657745],
#   [61000, 0.03146924823522568],
#   [62000, 0.05312684178352356],
#   [63000, 0.01806657575070858],
#   [64000, 0.039330244064331055],
#   [65000, 0.06844552606344223],
#   [66000, 0.03291796147823334],
#   [67000, 0.024187808856368065],
#   [68000, 0.05911436676979065],
#   [69000, 0.06520148366689682],
#   [70000, 0.045907847583293915],
#   [71000, 0.04425353929400444],
#   [72000, 0.05503630265593529],
#   [73000, 0.021559318527579308],
#   [74000, 0.0475974902510643],
#   [75000, 0.03377747908234596],
#   [76000, 0.021701671183109283],
#   [77000, 0.025071721524000168],
#   [78000, 0.054669760167598724],
#   [79000, 0.029559344053268433],
#   [80000, 0.018973812460899353],
#   [81000, 0.027734776958823204],
#   [82000, 0.06520950794219971],
#   [83000, 0.06618112325668335],
#   [84000, 0.052386146038770676],
#   [85000, 0.042416490614414215],
#   [86000, 0.043884724378585815],
#   [87000, 0.037451982498168945],
#   [88000, 0.0469958633184433],
#   [89000, 0.02847464010119438],
#   [90000, 0.05740021914243698],
#   [60000, 0.28102567441761495],
#   [61000, 0.29330574076622723],
#   [62000, 0.2883286198228598],
#   [63000, 0.2929749233648181],
#   [64000, 0.2752693401649594],
#   [65000, 0.26843821855261923],
#   [66000, 0.3223061061836779],
#   [67000, 0.3361821510270238],
#   [68000, 0.28401768889278173],
#   [69000, 0.3187864228151739],
#   [70000, 0.2582737183570862],
#   [71000, 0.2538251330703497],
#   [72000, 0.2756168096885085],
#   [73000, 0.2763641437701881],
#   [74000, 0.252316955991555],
#   [75000, 0.2724469831585884],
#   [76000, 0.2916682297922671],
#   [77000, 0.27286935918033123],
#   [78000, 0.24747720832005143],
#   [79000, 0.24981657702475787],
#   [80000, 0.2678341006487608],
#   [81000, 0.26353368455544113],
#   [82000, 0.2701895719394088],
#   [83000, 0.28030521038919687],
#   [84000, 0.266188753657043],
#   [85000, 0.29178627165034415],
#   [86000, 0.24079955577850343],
#   [87000, 0.26513773191720247],
#   [88000, 0.27162143524736165],
#   [89000, 0.27493766030296685],
#   [90000, 0.23992888309061527],
#   [91000, 0.23582800216972827],
#   [92000, 0.257767399456352],
#   [93000, 0.24162849413231016],
#   [94000, 0.2515240193344653],
#   [95000, 0.23205300565809012],
#   [96000, 0.24181709038093685],
#   [97000, 0.24875076923519374],
#   [98000, 0.21406387630850077],
#   [99000, 0.27394027061760423]],
#  '_label': 'FM_v2'}

# %%
import pickle

pkl_path = '/content/drive/MyDrive/FMPCC/FM-PCC/logs/avoiding-d3il/flow_matching_hp_tune1/H8_K20_Dmodels.diffusion.GaussianDiffusion/6/losses.pkl'

with open(pkl_path, 'rb') as f:
    data = pickle.load(f)

data_fm_hp = data
data_fm_hp['_label'] = 'FM HP Tune1'
data_fm_hp
# Out:
# {'training_losses': [[0, 0.6937376260757446],
#   [1000, 0.37265563011169434],
#   [2000, 0.2904079556465149],
#   [3000, 0.1919475495815277],
#   [4000, 0.08720411360263824],
#   [5000, 0.11036711931228638],
#   [6000, 0.12474948167800903],
#   [7000, 0.17950910329818726],
#   [8000, 0.10109047591686249],
#   [9000, 0.1273067146539688],
#   [10000, 0.12479039281606674],
#   [11000, 0.11847826093435287],
#   [12000, 0.11108972132205963],
#   [13000, 0.07486343383789062],
#   [14000, 0.10137107968330383],
#   [15000, 0.042075350880622864],
#   [16000, 0.07805758714675903],
#   [17000, 0.13954178988933563],
#   [18000, 0.09395003318786621],
#   [19000, 0.0957724079489708],
#   [20000, 0.09999348968267441],
#   [21000, 0.09330733120441437],
#   [22000, 0.06070556491613388],
#   [23000, 0.10561801493167877],
#   [24000, 0.0356174111366272],
#   [25000, 0.06981576979160309],
#   [26000, 0.11981716006994247],
#   [27000, 0.06908775120973587],
#   [28000, 0.04141463339328766],
#   [29000, 0.17233964800834656],
#   [30000, 0.06685464084148407],
#   [31000, 0.04267590492963791],
#   [32000, 0.1312985122203827],
#   [33000, 0.1500386893749237],
#   [34000, 0.07775576412677765],
#   [35000, 0.03449207916855812],
#   [36000, 0.11970343440771103],
#   [37000, 0.07907857745885849],
#   [38000, 0.0742223709821701],
#   [39000, 0.0937272161245346],
#   [99000, 0.2916272896155715]],
#  '_label': 'FM HP Tune1'}

# %%
import pickle

pkl_path = '/content/drive/MyDrive/FMPCC/FM-PCC/logs/avoiding-d3il/flow_matching/H8_K20_Dmodels.diffusion.GaussianDiffusion/6/losses.pkl'

with open(pkl_path, 'rb') as f:
    data = pickle.load(f)

data_fm = data
data_fm['_label'] = 'FM Baseline'
data_fm
# Out:
# {'training_losses': [[0, 0.949715793132782],
#   [1000, 0.5842266082763672],
#   [2000, 0.6078827381134033],
#   [3000, 0.40630480647087097],
#   [4000, 0.18648594617843628],
#   [5000, 0.21672600507736206],
#   [6000, 0.20866897702217102],
#   [7000, 0.3693673014640808],
#   [8000, 0.21442973613739014],
#   [9000, 0.23835155367851257],
#   [10000, 0.2528917193412781],
#   [11000, 0.36903542280197144],
#   [12000, 0.24370455741882324],
#   [13000, 0.15175023674964905],
#   [14000, 0.26657652854919434],
#   [15000, 0.17764143645763397],
#   [16000, 0.16501745581626892],
#   [17000, 0.2503030300140381],
#   [18000, 0.17005062103271484],
#   [19000, 0.20403704047203064],
#   [20000, 0.20795302093029022],
#   [21000, 0.18548300862312317],
#   [22000, 0.16434302926063538],
#   [23000, 0.1983177661895752],
#   [24000, 0.12333102524280548],
#   [25000, 0.10101346671581268],
#   [26000, 0.21400102972984314],
#   [27000, 0.1835465431213379],
#   [28000, 0.08523236960172653],
#   [29000, 0.27282261848449707],
#   [30000, 0.14688798785209656],
#   [31000, 0.16745802760124207],
#   [32000, 0.2260245978832245],
#   [33000, 0.2635684907436371],
#   [34000, 0.13766781985759735],
#   [35000, 0.05276568979024887],
#   [36000, 0.1496310532093048],
#   [37000, 0.12489835917949677],
#   [38000, 0.1286536157131195],
#   [39000, 0.12764962017536163],
#   [40000, 0.1439574956893921],
#   [41000, 0.06466497480869293],
#   [42000, 0.06724458932876587],
#   [43000, 0.072932168841362],
#   [44000, 0.06915190070867538],
#   [45000, 0.15642042458057404],
#   [46000, 0.10570794343948364],
#   [47000, 0.10458161681890488],
#   [48000, 0.04774092882871628],
#   [49000, 0.10398989915847778],
#   [50000, 0.13783983886241913],
#   [51000, 0.17214910686016083],
#   [52000, 0.16207802295684814],
#   [53000, 0.2596946656703949],
#   [54000, 0.14759689569473267],
#   [55000, 0.06952281296253204],
#   [56000, 0.07041345536708832],
#   [57000, 0.1544448733329773],
#   [58000, 0.15338076651096344],
#   [59000, 0.08863457292318344],
#   [60000, 0.19087177515029907],
#   [61000, 0.11308490484952927],
#   [62000, 0.15155932307243347],
#   [63000, 0.06632860004901886],
#   [64000, 0.1367952525615692],
#   [65000, 0.1193413957953453],
#   [66000, 0.2123471200466156],
#   [67000, 0.11687332391738892],
#   [68000, 0.08980949968099594],
#   [69000, 0.06490586698055267],
#   [70000, 0.19163411855697632],
#   [71000, 0.1280324012041092],
#   [72000, 0.07436171174049377],
#   [73000, 0.07351070642471313],
#   [74000, 0.2038675993680954],
#   [75000, 0.05568584054708481],
#   [76000, 0.1127074584364891],
#   [77000, 0.12120371311903],
#   [46000, 0.036148171273525806],
#   [47000, 0.03562696300446987],
#   [48000, 0.03531072292942554],
#   [49000, 0.038447835072875025],
#   [50000, 0.034153407672420144],
#   [51000, 0.03482907101628371],
#   [52000, 0.031368145318701864],
#   [53000, 0.03202604729682207],
#   [54000, 0.03558734096353874],
#   [55000, 0.03453853705650545],
#   [56000, 0.03307666288514156],
#   [57000, 0.030897538415156304],
#   [58000, 0.03098888646811247],
#   [59000, 0.03123363557970151],
#   [60000, 0.03090622801799327],
#   [61000, 0.030302731436677277],
#   [62000, 0.028860427814070135],
#   [63000, 0.03016760196071118],
#   [64000, 0.03317163034807891],
#   [65000, 0.02851523705525324],
#   [66000, 0.029428604582790285],
#   [67000, 0.032171356923063284],
#   [68000, 0.03172039178549312],
#   [69000, 0.02720837089349516],
#   [70000, 0.03299169649137184],
#   [71000, 0.025272796815261244],
#   [72000, 0.032043819956015795],
#   [73000, 0.03154121220111847],
#   [74000, 0.030380075452485472],
#   [75000, 0.027747410980518906],
#   [76000, 0.031241649587173015],
#   [77000, 0.029129725061357022],
#   [78000, 0.03037054985994473],
#   [79000, 0.029022764470428227],
#   [80000, 0.025594641282223166],
#   [81000, 0.028902730010449885],
#   [82000, 0.02816296723438427],
#   [83000, 0.029771350582595914],
#   [84000, 0.028548851679079234],
#   [85000, 0.029117652813438324],
#   [86000, 0.02734594538807869],
#   [87000, 0.027052832371555268],
#   [88000, 0.02817343999631703],
#   [89000, 0.03038078729296103],
#   [90000, 0.02944520869059488],
#   [91000, 0.0275787243177183],
#   [92000, 0.02802980805747211],
#   [93000, 0.02976722442312166],
#   [94000, 0.024425990441814066],
#   [95000, 0.03018003546865657],
#   [96000, 0.028005649547558277],
#   [97000, 0.028814391216728838],
#   [98000, 0.029007126186043022],
#   [99000, 0.025723139457404613]],
#  '_label': 'FM Baseline'}

# %% [markdown]
# Caution: for DPCC Seed 6 Training Logs, is patched from Wandb because the data lost in resume training and bugs in pkl logging(fixed now). So the under code is also different

# %%
import os, re, pickle
import numpy as np

target_dir = '/content/drive/MyDrive/FMPCC/FM-PCC/logs/avoiding-d3il/diffusion/H8_K20_Dmodels.GaussianDiffusion/6'

class FallbackUnpickler(pickle.Unpickler):
    def find_class(self, module, name):
        if "flow_matcher" in module:
            return type(name, (), {})
        return super().find_class(module, name)

def load_losses_pkl(path):
    with open(path, "rb") as f:
        d = FallbackUnpickler(f).load()
    out = {}
    for k, v in d.items():
        arr = np.array(v)
        if arr.ndim == 2 and arr.shape[1] == 2:
            out[k] = arr.astype(float)
    return out

pkl = load_losses_pkl(os.path.join(target_dir, "losses.pkl"))

# ── Paste W&B console output ──
WANDB_LOG_TEXT = r"""
Epoch 0: 100% 1000/1000 [01:21<00:00, 12.31it/s, a0_loss=0.0414, a0_loss_test=0.112, diffusion_loss=0.853, loss=0.426, loss_test=0.751, lr=0.0001, step=999]
2026-03-20 15:47:35Initial test loss:   0.7509, a0 loss:   0.1115
2026-03-20 15:50:14Epoch 1: 100% 1000/1000 [01:19<00:00, 12.57it/s, a0_loss=0.0371, a0_loss_test=0.0343, diffusion_loss=0.483, loss=0.241, loss_test=0.393, lr=0.0001, step=1999]
d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2})", "\n", text)
    rows = []
    for line in text.splitlines():
        if "Epoch" not in line or "step=" not in line:
            continue
        def grab(pat):
            m = re.search(pat, line)
            return float(m.group(1)) if m else np.nan
        step = grab(r"step=([0-9]+(?:\.[0-9]+)?(?:e\+?[0-9]+)?)")
        if np.isnan(step):
            continue
        step = int(step)
        rows.append((
            step,
            grab(r"(?<!\w)loss=([0-9]+(?:\.[0-9]+)?(?:e[+-]?[0-9]+)?)"),
            grab(r"(?<!\w)loss_test=([0-9]+(?:\.[0-9]+)?(?:e[+-]?[0-9]+)?)"),
            grab(r"(?<!\w)a0_loss=([0-9]+(?:\.[0-9]+)?(?:e[+-]?[0-9]+)?)"),
            grab(r"a0_loss_test=([0-9]+(?:\.[0-9]+)?(?:e[+-]?[0-9]+)?)"),
        ))
    if not rows:
        raise ValueError("No rows parsed.")
    return np.array(sorted(rows, key=lambda x: x[0]), dtype=float)

w = parse_console(WANDB_LOG_TEXT)

# ── Combine ──
def combine(local_arr, extra_steps, extra_vals):
    local_steps = local_arr[:, 0].astype(int)
    local_vals  = local_arr[:, 1].astype(float)
    local_set = set(local_steps.tolist())
    fin = np.isfinite(extra_vals)
    keep = np.array([s not in local_set for s in extra_steps]) & fin
    all_s = np.concatenate([extra_steps[keep], local_steps])
    all_v = np.concatenate([extra_vals[keep],  local_vals])
    order = np.argsort(all_s)
    return np.c_[all_s[order], all_v[order]]

SPECS = [
    ("training_losses",    1),
    ("test_losses",        2),
    ("training_a0_losses", 3),
    ("test_a0_losses",     4),
]

# ── Build output as plain dict of lists (same as pickle.load output) ──
data = {}
for pkl_key, col in SPECS:
    arr = combine(pkl[pkl_key], w[:, 0].astype(int), w[:, col])
    data[pkl_key] = [[int(row[0]), float(row[1])] for row in arr]

data_diff = data
data_diff['_label'] = 'Diffusion (patched)'
data_diff
# Out:
# {'training_losses': [[999, 0.426],
#   [1999, 0.241],
#   [2999, 0.0975],
#   [3999, 0.0783],
#   [4999, 0.0712],
#   [5999, 0.0993],
#   [6999, 0.0409],
#   [7999, 0.161],
#   [8999, 0.0664],
#   [9999, 0.114],
#   [10999, 0.0232],
#   [11999, 0.0416],
#   [12999, 0.205],
#   [13999, 0.0613],
#   [14999, 0.0498],
#   [15999, 0.0758],
#   [16999, 0.052],
#   [17999, 0.111],
#   [18999, 0.0341],
#   [20000, 0.0334],
#   [20999, 0.149],
#   [21999, 0.0812],
#   [22999, 0.0292],
#   [23999, 0.0146],
#   [24999, 0.022],
#   [25999, 0.146],
#   [26999, 0.0809],
#   [27999, 0.0505],
#   [28999, 0.0154],
#   [30000, 0.0226],
#   [30999, 0.0226],
#   [31999, 0.0559],
#   [32999, 0.0319],
#   [33999, 0.0359],
#   [34999, 0.0359],
#   [35999, 0.0297],
#   [36999, 0.0197],
#   [37999, 0.053],
#   [38999, 0.0213],
#   [40000, 0.037724971771240234],
#   [41000, 0.07924128323793411],
#   [42000, 0.08187031745910645],
#   [43000, 0.07980509102344513],
#   [44000, 0.06303571164608002],
#   [45000, 0.029415711760520935],
#   [46000, 0.03273249417543411],
#   [47000, 0.08853431791067123],
#   [48000, 0.05066120624542236],
#   [49000, 0.059963177889585495],
#   [49000, 0.012094216053374112],
#   [50000, 0.00869606653082883],
#   [51000, 0.009255438903346657],
#   [52000, 0.01223477765917778],
#   [53000, 0.009720400674268603],
#   [54000, 0.008584715715842321],
#   [55000, 0.01207696829282213],
#   [56000, 0.00968345563451294],
#   [57000, 0.009163846500450745],
#   [58000, 0.009361330305691808],
#   [59000, 0.008365684364107437],
#   [60000, 0.008571682336332742],
#   [61000, 0.008347303096670658],
#   [62000, 0.007930015689926222],
#   [63000, 0.009225382901495322],
#   [64000, 0.009879283759510145],
#   [65000, 0.008287439538398757],
#   [66000, 0.008349464721977711],
#   [67000, 0.008822236413834617],
#   [68000, 0.007599866846576333],
#   [69000, 0.010047843441425357],
#   [70000, 0.010684632865595631],
#   [71000, 0.008831372581189498],
#   [72000, 0.009425477928598412],
#   [73000, 0.008225063520367257],
#   [74000, 0.008609884605975822],
#   [75000, 0.007676657133270055],
#   [76000, 0.00824604622030165],
#   [77000, 0.008101122436346486],
#   [78000, 0.00970936726545915],
#   [79000, 0.011161185942473822],
#   [80000, 0.008514217146439478],
#   [81000, 0.00816270163806621],
#   [82000, 0.0085510824091034],
#   [83000, 0.008674656143411993],
#   [84000, 0.009362589895608835],
#   [85000, 0.008370941785397008],
#   [86000, 0.009731305503519251],
#   [87000, 0.008003304558806122],
#   [88000, 0.00758500536205247],
#   [89000, 0.006858849302516319],
#   [90000, 0.007950713990212535],
#   [91000, 0.008787700572866016],
#   [92000, 0.007648857003368903],
#   [93000, 0.009020675524661783],
#   [94000, 0.007958867899433245],
#   [95000, 0.00679593705048319],
#   [96000, 0.007148264434072189],
#   [97000, 0.0094493536563823],
#   [98000, 0.00850513985089492],
#   [99000, 0.007069106642738916]],
#  '_label': 'Diffusion (patched)'}

# %% [markdown]
# ### Data Analysis

# %%
import numpy as np
import matplotlib.pyplot as plt

# ── 4 runs: HP1 FM, HP1 Diffusion, HP2 FM, HP2 Diffusion ──
all_runs = [data_fm_hp, data_fm, data_diff, data_fm_v2]
colors   = ['tab:green', 'tab:blue', 'tab:red', 'tab:orange']

fig, axes = plt.subplots(2, 2, figsize=(16, 10))

for ax, key, title in [
    (axes[0,0], 'test_losses',       'Test Loss'),
    (axes[0,1], 'test_a0_losses',    'Test a0 Loss'),
    (axes[1,0], 'training_losses',   'Training Loss'),
    (axes[1,1], 'training_a0_losses','Training a0 Loss'),
]:
    for run, c in zip(all_runs, colors):
        arr = np.array(run[key])
        ax.plot(arr[:,0], arr[:,1], label=run['_label'], color=c, alpha=0.8)
    ax.set_xlabel('Step'); ax.set_ylabel('Loss')
    ax.set_title(title); ax.legend(); ax.grid(True, alpha=0.3)

plt.suptitle('4-Run Comparison — avoiding-d3il / H8_K20 / seed 6',
             fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig('4run_comparison.png', dpi=150)
plt.show()

# ── Summary stats ──
print(f"\n{'='*86}")
print(f"{'Run':<22} {'Final Test Loss':>16} {'Min Test Loss':>16} {'Final a0 Test':>16} {'Min a0 Test':>14}")
print(f"{'='*86}")
for run in all_runs:
    tl = np.array(run['test_losses'])
    a0 = np.array(run['test_a0_losses'])
    print(f"{run['_label']:<22} {tl[-1,1]:>16.6f} {tl[:,1].min():>16.6f} {a0[-1,1]:>16.6f} {a0[:,1].min():>14.6f}")

# ── Convergence speed: step where test loss first drops below threshold ──
print(f"\n{'='*86}")
print("Convergence speed (first step where test_loss < threshold):")
for thresh in [0.20, 0.15, 0.12]:
    print(f"\n  threshold = {thresh}")
    for run, c in zip(all_runs, colors):
        arr = np.array(run['test_losses'])
        below = arr[arr[:,1] < thresh]
        step = int(below[0,0]) if len(below) > 0 else None
        print(f"    {run['_label']:<22}: step {step}" if step else f"    {run['_label']:<22}: never reached")

# ── Overfitting gap (train vs test) at final step ──
print(f"\n{'='*86}")
print("Overfitting gap at final step (train_loss - test_loss):")
for run in all_runs:
    tr = np.array(run['training_losses'])
    te = np.array(run['test_losses'])
    n  = min(len(tr), len(te))
    gap = tr[n-1,1] - te[n-1,1]
    print(f"  {run['_label']:<22}: {gap:+.6f}  ({'overfit' if gap < -0.01 else 'underfit' if gap > 0.01 else 'balanced'})")
# Out:
# ======================================================================================
# Run                     Final Test Loss    Min Test Loss    Final a0 Test    Min a0 Test
# ======================================================================================
# FM HP Tune1                    0.063971         0.061796         0.291627       0.285329
# FM Baseline                    0.116854         0.115070         0.025723       0.024426
# Diffusion (patched)            0.027634         0.026863         0.007069       0.006796
# FM_v2                          0.047213         0.044013         0.273940       0.214064
#
# ======================================================================================
# Convergence speed (first step where test_loss < threshold):
#
#   threshold = 0.2
#     FM HP Tune1           : step 3000
#     FM Baseline           : step 14000
#     Diffusion (patched)   : step 2999
#     FM_v2                 : step 2000
#
#   threshold = 0.15
#     FM HP Tune1           : step 4000
#     FM Baseline           : step 39000
#     Diffusion (patched)   : step 3999
#     FM_v2                 : step 3000
#
#   threshold = 0.12
#     FM HP Tune1           : step 7000
#     FM Baseline           : step 71000
#     Diffusion (patched)   : step 4999
#     FM_v2                 : step 5000
#
# ======================================================================================
# Overfitting gap at final step (train_loss - test_loss):
#   FM HP Tune1           : -0.035390  (overfit)
#   FM Baseline           : -0.059423  (overfit)
#   Diffusion (patched)   : -0.015783  (overfit)
#   FM_v2                 : -0.019283  (overfit)

# %%
import numpy as np
import matplotlib.pyplot as plt

all_runs = [data_fm_hp, data_fm, data_diff]
colors = ['tab:green', 'tab:blue', 'tab:red']

fig, axes = plt.subplots(2, 2, figsize=(16, 10))

for ax, key, title in [
    (axes[0,0], 'test_losses',       'Test Loss'),
    (axes[0,1], 'test_a0_losses',    'Test a0 Loss'),
    (axes[1,0], 'training_losses',   'Training Loss'),
    (axes[1,1], 'training_a0_losses','Training a0 Loss'),
]:
    for run, c in zip(all_runs, colors):
        arr = np.array(run[key])
        ax.plot(arr[:,0], arr[:,1], label=run['_label'], color=c, alpha=0.8)
    ax.set_xlabel('Step'); ax.set_ylabel('Loss')
    ax.set_title(title); ax.legend(); ax.grid(True, alpha=0.3)

plt.suptitle('3-Run Comparison — avoiding-d3il / H8_K20 / seed 6', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.savefig('3run_comparison.png', dpi=150)
plt.show()

# ── Summary stats ──
print(f"\n{'='*70}")
print(f"{'Run':<22} {'Final Test Loss':>16} {'Min Test Loss':>16} {'Final a0 Test':>16} {'Min a0 Test':>14}")
print(f"{'='*70}")
for run in all_runs:
    tl = np.array(run['test_losses'])
    a0 = np.array(run['test_a0_losses'])
    print(f"{run['_label']:<22} {tl[-1,1]:>16.6f} {tl[:,1].min():>16.6f} {a0[-1,1]:>16.6f} {a0[:,1].min():>14.6f}")

# ── Convergence speed: step where test loss first drops below threshold ──
print(f"\n{'='*70}")
print("Convergence speed (first step where test_loss < threshold):")
for thresh in [0.20, 0.15, 0.12]:
    print(f"\n  threshold = {thresh}")
    for run, c in zip(all_runs, colors):
        arr = np.array(run['test_losses'])
        below = arr[arr[:,1] < thresh]
        step = int(below[0,0]) if len(below) > 0 else None
        print(f"    {run['_label']:<22}: step {step}" if step else f"    {run['_label']:<22}: never reached")

# ── Overfitting gap (train vs test) at final step ──
print(f"\n{'='*70}")
print("Overfitting gap at final step (train_loss - test_loss):")
for run in all_runs:
    tr = np.array(run['training_losses'])
    te = np.array(run['test_losses'])
    n = min(len(tr), len(te))
    gap = tr[n-1,1] - te[n-1,1]
    print(f"  {run['_label']:<22}: {gap:+.6f}  ({'overfit' if gap < -0.01 else 'underfit' if gap > 0.01 else 'balanced'})")
# Out:
# ======================================================================
# Run                     Final Test Loss    Min Test Loss    Final a0 Test    Min a0 Test
# ======================================================================
# FM HP Tune1                    0.063971         0.061796         0.291627       0.285329
# FM Baseline                    0.116854         0.115070         0.025723       0.024426
# Diffusion (patched)            0.027634         0.026863         0.007069       0.006796
#
# ======================================================================
# Convergence speed (first step where test_loss < threshold):
#
#   threshold = 0.2
#     FM HP Tune1           : step 3000
#     FM Baseline           : step 14000
#     Diffusion (patched)   : step 2999
#
#   threshold = 0.15
#     FM HP Tune1           : step 4000
#     FM Baseline           : step 39000
#     Diffusion (patched)   : step 3999
#
#   threshold = 0.12
#     FM HP Tune1           : step 7000
#     FM Baseline           : step 71000
#     Diffusion (patched)   : step 4999
#
# ======================================================================
# Overfitting gap at final step (train_loss - test_loss):
#   FM HP Tune1           : -0.035390  (overfit)
#   FM Baseline           : -0.059423  (overfit)
#   Diffusion (patched)   : -0.015783  (overfit)

# %% [markdown]
# ## Load the Plan .npz logs

# %%
import numpy as np

# Path to your specific file
file_path = ''

# allow_pickle=True is MANDATORY for 'object' dtypes in npz
# Using a context manager ('with') is safer for file I/O
with np.load(file_path, allow_pickle=True) as data:

    # Force NumPy to print the entire array instead of truncating with "..."
    np.set_printoptions(threshold=np.inf, precision=6, suppress=True)

    print(f"{'Key':<25} | {'Shape':<15} | {'Data Type':<10}")
    print("=" * 60)

    for key in data.files:
        array = data[key]

        # Header for each entry
        print(f"{key:<25} | {str(array.shape):<15} | {str(array.dtype):<10}")

        # Logic to handle potential object arrays or nested dicts
        if array.dtype == 'object':
            print("--- Object Content ---")
            print(array.tolist()) # Converting to list often reveals the internal structure
        else:
            print(array)

        print("-" * 60)
